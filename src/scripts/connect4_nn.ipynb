# %%
# %matplotlib inline

import numpy as np
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data

from sklearn.model_selection import train_test_split


torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.manual_seed(999)
np.random.seed(0)

# %%
n_epocs = 1000
batch_size = 1
test_size = 0.2
learning_rate = 0.002 * (batch_size / 1024.0)
momentum = 0.0

# %%
class Connect4Dataset(data.Dataset):
    def __init__(self, boards, values):
        assert len(boards) == len(values)
        self.boards = boards
        self.values = values
        
    def __len__(self):
        return len(self.boards)
    
    def __getitem__(self, idx):
        return self.boards[idx], self.values[idx]

boards = torch.load('/home/richard/Downloads/connect4_boards.pth').numpy()
values = torch.load('/home/richard/Downloads/connect4_values.pth').numpy()

# Here we don't want to have the player to move channel
boards = boards[:, 1:]

board_train, board_test, value_train, value_test = train_test_split(boards, values, test_size=test_size, shuffle=True)

# %%
from src.connect4.utils import augment_data

# board_train, value_train = augment_data(board_train, value_train)

train = Connect4Dataset(torch.from_numpy(board_train), torch.from_numpy(value_train))
test = Connect4Dataset(torch.from_numpy(board_test), torch.from_numpy(value_test))

train_gen = data.DataLoader(train, batch_size, shuffle=True)
test_gen = data.DataLoader(test, batch_size, shuffle=True)

# %%
from src.connect4.neural import value_net as net

def init_normal(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.0000001)
    elif type(m) == nn.Conv2d:
        nn.init.normal_(m.weight, std=0.0000001)
    elif type(m) == nn.BatchNorm2d:
        nn.init.normal_(m.weight, std=0.0000001)
#         nn.init.constant_(m.bias, 0)

# net.apply(init_normal)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Sequential(
#       (0): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.01)
#     )
#     (1): Sequential(
#       (0): ResidualLayer(
#         (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): LeakyReLU(negative_slope=0.01)
#       )
#       (1): ResidualLayer(
#         (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): LeakyReLU(negative_slope=0.01)
#       )
#       (2): ResidualLayer(
#         (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): LeakyReLU(negative_slope=0.01)
#       )
#     )
#     (2): ValueHead(
#       (conv1): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#       (batch_norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.01)
#       (fcN): Sequential(
#         (0): Linear(in_features=42, out_features=42, bias=True)
#         (1): Linear(in_features=42, out_features=42, bias=True)
#         (2): Linear(in_features=42, out_features=42, bias=True)
#         (3): Linear(in_features=42, out_features=42, bias=True)
#       )
#     )
#   )
#   (1): ValueTip(
#     (fc1): Linear(in_features=42, out_features=1, bias=True)
#     (tanh): Tanh()
#   )
# )

# %%
def categorise_predictions(preds):
    preds = preds * 3.0
    torch.floor_(preds)
    preds = preds / 2.0
    return preds

class Stats():
    def __init__(self):
        self.n = 0
        self.average_value = 0.0
        self.total_loss = 0.0
        self.smallest = 1.0
        self.largest = 0.0
        self.correct = {i : 0 for i in [0.0, 0.5, 1.0]}
        self.total = {i : 0 for i in [0.0, 0.5, 1.0]}
    
    @property
    def loss(self):
        return self.total_loss / self.n
    
    @property
    def accuracy(self):
        return float(sum(self.correct.values())) / self.n

    @property
    def average(self):
        return self.average_value / self.n
        

    def __repr__(self):
        x = "Average loss:  " + "{:.5f}".format(self.loss) + \
            ",  Accuracy:  " + "{:.5f}".format(self.accuracy) + \
            ",  Smallest:  " + "{:.5f}".format(self.smallest) + \
            ",  Largest:  " + "{:.5f}".format(self.largest) + \
            ",  Average:  " + "{:.5f}".format(self.average)
        
        for k in self.correct:
            x += "\nCategory, # Members, # Correct Predictions:  {}, {}, {}".format(
                k,
                self.total[k],
                self.correct[k])
        return x
    
    def update(self, outputs, values, loss):
        self.n += len(values)
        self.average_value += outputs.sum().item()
        self.total_loss += loss.item() * len(values)
        self.smallest = min(self.smallest, torch.min(outputs).item())
        self.largest = max(self.largest, torch.max(outputs).item())

        categories = categorise_predictions(outputs)
        values = values.view(-1)
        categories = categories.view(-1)

        for k in self.correct:
            idx = (values == k).nonzero()
            self.total[k] += len(idx)
            self.correct[k] += len(torch.eq(categories[idx], values[idx]).nonzero())

# %%
# criterion = nn.MSELoss()
# criterion2 = nn.MSELoss()
criterion = nn.L1Loss()
criterion2 = nn.L1Loss()

# optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum)
optimizer = optim.Adam(net.parameters())

# # For classifier
# weight = torch.tensor([float(len(value_train) - len(value_train[value_train == i])) / len(value_train) for i in [1.0, 0.5, 0.0]])
# Actually isn't this the correct weight?
# weight = [1.0 / (3.0 * len(value_train[value_train == i]) / len(value_train)) for i in [1.0, 0.5, 0.0]]
# weight = weight.to(device)
# criterion = nn.CrossEntropyLoss(weight=weight)

# %%
# alternatively load it
# assert(False)
# checkpoint = torch.load('/home/richard/Downloads/nn.pth')
# net.load_state_dict(checkpoint['net_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %%
# Get an idea of how the initialisation is
test_stats = Stats()
with torch.set_grad_enabled(False):
    net = net.eval()
    for board, value in test_gen:
        board, value = board.to(device), value.to(device)

        output = net(board)
        loss = criterion2(output, value)

        test_stats.update(output, value, loss)

print("Initial Test Stats:\n", test_stats)
# Out:
# Initial Test Stats:
#  Average loss:  0.24830,  Accuracy:  0.09458,  Smallest:  0.45195,  Largest:  0.45346,  Average:  0.45278
# Category, # Members, # Correct Predictions:  0.0, 3300, 0
# Category, # Members, # Correct Predictions:  0.5, 1278, 1278
# Category, # Members, # Correct Predictions:  1.0, 8934, 0

# %%
# %%time

from laplotter import LossAccPlotter
from visdom import Visdom

viz = Visdom()
plotter = LossAccPlotter()

for epoch in range(n_epocs):
    
    net = net.train()
    train_stats = Stats()
    test_stats = Stats()
    
    for board, value in train_gen:
        board, value = board.to(device), value.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        output = net(board)
        loss = criterion(output, value)
        loss.backward()
        optimizer.step()
        
        train_stats.update(output, value, loss)

    # validate
    with torch.set_grad_enabled(False):
        net = net.eval()
        for board, value in test_gen:
            board, value = board.to(device), value.to(device)

            output = net(board)
            loss = criterion2(output, value)
            
            test_stats.update(output, value, loss)
            
    print("Epoch:  ", epoch, "  Train:\n", train_stats, "\nTest:\n", test_stats)
    plotter.add_values(epoch,
                       loss_train=train_stats.loss, acc_train=train_stats.average - train_stats.smallest,
                       loss_val=test_stats.loss, acc_val=test_stats.average - test_stats.smallest)
    if epoch == 0:
        win = viz.matplot(plotter.fig)
    else:
        viz.matplot(plotter.fig, win=win)
        
    torch.save({
        'net_state_dict': net.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()},
        '/home/richard/Downloads/nn/nn__now_linear' + str(epoch) + '.pth')
            

print('Finished Training')
# Out:
# WARNING:root:Setting up a new session...
# Epoch:   0   Train:
#  Average loss:  0.05398,  Accuracy:  0.35537,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70856
# Category, # Members, # Correct Predictions:  0.0, 13335, 12482
# Category, # Members, # Correct Predictions:  0.5, 5171, 1543
# Category, # Members, # Correct Predictions:  1.0, 35539, 5181
# Test:
#  Average loss:  0.11165,  Accuracy:  0.26066,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.74342
# Category, # Members, # Correct Predictions:  0.0, 3300, 2436
# Category, # Members, # Correct Predictions:  0.5, 1278, 312
# Category, # Members, # Correct Predictions:  1.0, 8934, 774
# Epoch:   1   Train:
#  Average loss:  0.06277,  Accuracy:  0.29337,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71083
# Category, # Members, # Correct Predictions:  0.0, 13335, 12202
# Category, # Members, # Correct Predictions:  0.5, 5171, 1272
# Category, # Members, # Correct Predictions:  1.0, 35539, 2381
# Test:
#  Average loss:  0.10652,  Accuracy:  0.27516,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72266
# Category, # Members, # Correct Predictions:  0.0, 3300, 2647
# Category, # Members, # Correct Predictions:  0.5, 1278, 273
# Category, # Members, # Correct Predictions:  1.0, 8934, 798
# Epoch:   2   Train:
#  Average loss:  0.06924,  Accuracy:  0.28230,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70898
# Category, # Members, # Correct Predictions:  0.0, 13335, 12179
# Category, # Members, # Correct Predictions:  0.5, 5171, 986
# Category, # Members, # Correct Predictions:  1.0, 35539, 2092
# Test:
#  Average loss:  0.10907,  Accuracy:  0.28256,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72664
# Category, # Members, # Correct Predictions:  0.0, 3300, 2487
# Category, # Members, # Correct Predictions:  0.5, 1278, 404
# Category, # Members, # Correct Predictions:  1.0, 8934, 927
# Epoch:   3   Train:
#  Average loss:  0.06745,  Accuracy:  0.28722,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70952
# Category, # Members, # Correct Predictions:  0.0, 13335, 12077
# Category, # Members, # Correct Predictions:  0.5, 5171, 1304
# Category, # Members, # Correct Predictions:  1.0, 35539, 2142
# Test:
#  Average loss:  0.11224,  Accuracy:  0.26155,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72895
# Category, # Members, # Correct Predictions:  0.0, 3300, 2512
# Category, # Members, # Correct Predictions:  0.5, 1278, 325
# Category, # Members, # Correct Predictions:  1.0, 8934, 697
# Epoch:   4   Train:
#  Average loss:  0.06988,  Accuracy:  0.28232,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71331
# Category, # Members, # Correct Predictions:  0.0, 13335, 11851
# Category, # Members, # Correct Predictions:  0.5, 5171, 1355
# Category, # Members, # Correct Predictions:  1.0, 35539, 2052
# Test:
#  Average loss:  0.11243,  Accuracy:  0.30173,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.69047
# Category, # Members, # Correct Predictions:  0.0, 3300, 2738
# Category, # Members, # Correct Predictions:  0.5, 1278, 335
# Category, # Members, # Correct Predictions:  1.0, 8934, 1004
# Epoch:   5   Train:
#  Average loss:  0.07174,  Accuracy:  0.28188,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71099
# Category, # Members, # Correct Predictions:  0.0, 13335, 11893
# Category, # Members, # Correct Predictions:  0.5, 5171, 1212
# Category, # Members, # Correct Predictions:  1.0, 35539, 2129
# Test:
#  Average loss:  0.11416,  Accuracy:  0.25525,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.73874
# Category, # Members, # Correct Predictions:  0.0, 3300, 2457
# Category, # Members, # Correct Predictions:  0.5, 1278, 296
# Category, # Members, # Correct Predictions:  1.0, 8934, 696
# Epoch:   6   Train:
#  Average loss:  0.07054,  Accuracy:  0.28484,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71134
# Category, # Members, # Correct Predictions:  0.0, 13335, 11937
# Category, # Members, # Correct Predictions:  0.5, 5171, 1206
# Category, # Members, # Correct Predictions:  1.0, 35539, 2251
# Test:
#  Average loss:  0.11681,  Accuracy:  0.26044,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.75460
# Category, # Members, # Correct Predictions:  0.0, 3300, 2301
# Category, # Members, # Correct Predictions:  0.5, 1278, 303
# Category, # Members, # Correct Predictions:  1.0, 8934, 915
# Epoch:   7   Train:
#  Average loss:  0.07279,  Accuracy:  0.28963,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71281
# Category, # Members, # Correct Predictions:  0.0, 13335, 11789
# Category, # Members, # Correct Predictions:  0.5, 5171, 1283
# Category, # Members, # Correct Predictions:  1.0, 35539, 2581
# Test:
#  Average loss:  0.10950,  Accuracy:  0.24970,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.76251
# Category, # Members, # Correct Predictions:  0.0, 3300, 2242
# Category, # Members, # Correct Predictions:  0.5, 1278, 389
# Category, # Members, # Correct Predictions:  1.0, 8934, 743
# Epoch:   8   Train:
#  Average loss:  0.07293,  Accuracy:  0.28602,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70687
# Category, # Members, # Correct Predictions:  0.0, 13335, 11998
# Category, # Members, # Correct Predictions:  0.5, 5171, 1234
# Category, # Members, # Correct Predictions:  1.0, 35539, 2226
# Test:
#  Average loss:  0.11286,  Accuracy:  0.26569,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72453
# Category, # Members, # Correct Predictions:  0.0, 3300, 2547
# Category, # Members, # Correct Predictions:  0.5, 1278, 296
# Category, # Members, # Correct Predictions:  1.0, 8934, 747
# Epoch:   9   Train:
#  Average loss:  0.07029,  Accuracy:  0.28597,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71343
# Category, # Members, # Correct Predictions:  0.0, 13335, 11882
# Category, # Members, # Correct Predictions:  0.5, 5171, 1230
# Category, # Members, # Correct Predictions:  1.0, 35539, 2343
# Test:
#  Average loss:  0.10464,  Accuracy:  0.28086,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70582
# Category, # Members, # Correct Predictions:  0.0, 3300, 2739
# Category, # Members, # Correct Predictions:  0.5, 1278, 325
# Category, # Members, # Correct Predictions:  1.0, 8934, 731
# Epoch:   10   Train:
#  Average loss:  0.07006,  Accuracy:  0.28933,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70982
# Category, # Members, # Correct Predictions:  0.0, 13335, 11973
# Category, # Members, # Correct Predictions:  0.5, 5171, 1244
# Category, # Members, # Correct Predictions:  1.0, 35539, 2420
# Test:
#  Average loss:  0.11793,  Accuracy:  0.28486,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71578
# Category, # Members, # Correct Predictions:  0.0, 3300, 2778
# Category, # Members, # Correct Predictions:  0.5, 1278, 28
# Category, # Members, # Correct Predictions:  1.0, 8934, 1043
# Epoch:   11   Train:
#  Average loss:  0.07741,  Accuracy:  0.28273,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71409
# Category, # Members, # Correct Predictions:  0.0, 13335, 11787
# Category, # Members, # Correct Predictions:  0.5, 5171, 1013
# Category, # Members, # Correct Predictions:  1.0, 35539, 2480
# Test:
#  Average loss:  0.10802,  Accuracy:  0.23431,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72585
# Category, # Members, # Correct Predictions:  0.0, 3300, 2714
# Category, # Members, # Correct Predictions:  0.5, 1278, 156
# Category, # Members, # Correct Predictions:  1.0, 8934, 296
# Epoch:   12   Train:
#  Average loss:  0.07413,  Accuracy:  0.27838,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71371
# Category, # Members, # Correct Predictions:  0.0, 13335, 11785
# Category, # Members, # Correct Predictions:  0.5, 5171, 1182
# Category, # Members, # Correct Predictions:  1.0, 35539, 2078
# Test:
#  Average loss:  0.10841,  Accuracy:  0.29936,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71579
# Category, # Members, # Correct Predictions:  0.0, 3300, 2592
# Category, # Members, # Correct Predictions:  0.5, 1278, 352
# Category, # Members, # Correct Predictions:  1.0, 8934, 1101
# Epoch:   13   Train:
#  Average loss:  0.07267,  Accuracy:  0.28515,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71257
# Category, # Members, # Correct Predictions:  0.0, 13335, 11823
# Category, # Members, # Correct Predictions:  0.5, 5171, 1274
# Category, # Members, # Correct Predictions:  1.0, 35539, 2314
# Test:
#  Average loss:  0.12415,  Accuracy:  0.36027,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.66158
# Category, # Members, # Correct Predictions:  0.0, 3300, 2975
# Category, # Members, # Correct Predictions:  0.5, 1278, 109
# Category, # Members, # Correct Predictions:  1.0, 8934, 1784
# Epoch:   14   Train:
#  Average loss:  0.07122,  Accuracy:  0.28419,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71264
# Category, # Members, # Correct Predictions:  0.0, 13335, 12026
# Category, # Members, # Correct Predictions:  0.5, 5171, 1069
# Category, # Members, # Correct Predictions:  1.0, 35539, 2264
# Test:
#  Average loss:  0.11508,  Accuracy:  0.26273,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.69757
# Category, # Members, # Correct Predictions:  0.0, 3300, 2927
# Category, # Members, # Correct Predictions:  0.5, 1278, 22
# Category, # Members, # Correct Predictions:  1.0, 8934, 601
# Epoch:   15   Train:
#  Average loss:  0.07413,  Accuracy:  0.27416,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71354
# Category, # Members, # Correct Predictions:  0.0, 13335, 11912
# Category, # Members, # Correct Predictions:  0.5, 5171, 1023
# Category, # Members, # Correct Predictions:  1.0, 35539, 1882
# Test:
#  Average loss:  0.11227,  Accuracy:  0.22091,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.74717
# Category, # Members, # Correct Predictions:  0.0, 3300, 2629
# Category, # Members, # Correct Predictions:  0.5, 1278, 85
# Category, # Members, # Correct Predictions:  1.0, 8934, 271
# Epoch:   16   Train:
#  Average loss:  0.07180,  Accuracy:  0.27564,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71349
# Category, # Members, # Correct Predictions:  0.0, 13335, 11899
# Category, # Members, # Correct Predictions:  0.5, 5171, 1179
# Category, # Members, # Correct Predictions:  1.0, 35539, 1819
# Test:
#  Average loss:  0.11240,  Accuracy:  0.26147,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.68759
# Category, # Members, # Correct Predictions:  0.0, 3300, 2843
# Category, # Members, # Correct Predictions:  0.5, 1278, 254
# Category, # Members, # Correct Predictions:  1.0, 8934, 436
# Epoch:   17   Train:
#  Average loss:  0.07280,  Accuracy:  0.26915,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71042
# Category, # Members, # Correct Predictions:  0.0, 13335, 12049
# Category, # Members, # Correct Predictions:  0.5, 5171, 972
# Category, # Members, # Correct Predictions:  1.0, 35539, 1525
# Test:
#  Average loss:  0.10860,  Accuracy:  0.26739,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70606
# Category, # Members, # Correct Predictions:  0.0, 3300, 2750
# Category, # Members, # Correct Predictions:  0.5, 1278, 292
# Category, # Members, # Correct Predictions:  1.0, 8934, 571
# Epoch:   18   Train:
#  Average loss:  0.06974,  Accuracy:  0.29318,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71043
# Category, # Members, # Correct Predictions:  0.0, 13335, 12094
# Category, # Members, # Correct Predictions:  0.5, 5171, 1120
# Category, # Members, # Correct Predictions:  1.0, 35539, 2631
# Test:
#  Average loss:  0.10920,  Accuracy:  0.28693,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71708
# Category, # Members, # Correct Predictions:  0.0, 3300, 2716
# Category, # Members, # Correct Predictions:  0.5, 1278, 161
# Category, # Members, # Correct Predictions:  1.0, 8934, 1000
# Epoch:   19   Train:
#  Average loss:  0.07449,  Accuracy:  0.27980,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70555
# Category, # Members, # Correct Predictions:  0.0, 13335, 11951
# Category, # Members, # Correct Predictions:  0.5, 5171, 1261
# Category, # Members, # Correct Predictions:  1.0, 35539, 1910
# Test:
#  Average loss:  0.12400,  Accuracy:  0.25673,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.65513
# Category, # Members, # Correct Predictions:  0.0, 3300, 3046
# Category, # Members, # Correct Predictions:  0.5, 1278, 15
# Category, # Members, # Correct Predictions:  1.0, 8934, 408
# Epoch:   20   Train:
#  Average loss:  0.06959,  Accuracy:  0.27361,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70888
# Category, # Members, # Correct Predictions:  0.0, 13335, 12050
# Category, # Members, # Correct Predictions:  0.5, 5171, 1333
# Category, # Members, # Correct Predictions:  1.0, 35539, 1404
# Test:
#  Average loss:  0.10679,  Accuracy:  0.26569,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.69481
# Category, # Members, # Correct Predictions:  0.0, 3300, 2722
# Category, # Members, # Correct Predictions:  0.5, 1278, 401
# Category, # Members, # Correct Predictions:  1.0, 8934, 467
# Epoch:   21   Train:
#  Average loss:  0.07088,  Accuracy:  0.27022,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71066
# Category, # Members, # Correct Predictions:  0.0, 13335, 11929
# Category, # Members, # Correct Predictions:  0.5, 5171, 1277
# Category, # Members, # Correct Predictions:  1.0, 35539, 1398
# Test:
#  Average loss:  0.11068,  Accuracy:  0.23542,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.75125
# Category, # Members, # Correct Predictions:  0.0, 3300, 2194
# Category, # Members, # Correct Predictions:  0.5, 1278, 469
# Category, # Members, # Correct Predictions:  1.0, 8934, 518
# Epoch:   22   Train:
#  Average loss:  0.06986,  Accuracy:  0.28510,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71235
# Category, # Members, # Correct Predictions:  0.0, 13335, 11979
# Category, # Members, # Correct Predictions:  0.5, 5171, 1263
# Category, # Members, # Correct Predictions:  1.0, 35539, 2166
# Test:
#  Average loss:  0.11740,  Accuracy:  0.28700,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.66281
# Category, # Members, # Correct Predictions:  0.0, 3300, 2918
# Category, # Members, # Correct Predictions:  0.5, 1278, 271
# Category, # Members, # Correct Predictions:  1.0, 8934, 689
# Epoch:   23   Train:
#  Average loss:  0.06933,  Accuracy:  0.27453,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70988
# Category, # Members, # Correct Predictions:  0.0, 13335, 12081
# Category, # Members, # Correct Predictions:  0.5, 5171, 1152
# Category, # Members, # Correct Predictions:  1.0, 35539, 1604
# Test:
#  Average loss:  0.11213,  Accuracy:  0.25659,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.69649
# Category, # Members, # Correct Predictions:  0.0, 3300, 2891
# Category, # Members, # Correct Predictions:  0.5, 1278, 65
# Category, # Members, # Correct Predictions:  1.0, 8934, 511
# Epoch:   24   Train:
#  Average loss:  0.07439,  Accuracy:  0.26737,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71311
# Category, # Members, # Correct Predictions:  0.0, 13335, 12089
# Category, # Members, # Correct Predictions:  0.5, 5171, 809
# Category, # Members, # Correct Predictions:  1.0, 35539, 1552
# Test:
#  Average loss:  0.11053,  Accuracy:  0.25999,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72675
# Category, # Members, # Correct Predictions:  0.0, 3300, 2530
# Category, # Members, # Correct Predictions:  0.5, 1278, 308
# Category, # Members, # Correct Predictions:  1.0, 8934, 675
# Epoch:   25   Train:
#  Average loss:  0.06895,  Accuracy:  0.27002,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71377
# Category, # Members, # Correct Predictions:  0.0, 13335, 11998
# Category, # Members, # Correct Predictions:  0.5, 5171, 1156
# Category, # Members, # Correct Predictions:  1.0, 35539, 1439
# Test:
#  Average loss:  0.11413,  Accuracy:  0.22462,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.74553
# Category, # Members, # Correct Predictions:  0.0, 3300, 2498
# Category, # Members, # Correct Predictions:  0.5, 1278, 204
# Category, # Members, # Correct Predictions:  1.0, 8934, 333
# Epoch:   26   Train:
#  Average loss:  0.07158,  Accuracy:  0.28841,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71555
# Category, # Members, # Correct Predictions:  0.0, 13335, 11852
# Category, # Members, # Correct Predictions:  0.5, 5171, 1216
# Category, # Members, # Correct Predictions:  1.0, 35539, 2519
# Test:
#  Average loss:  0.11093,  Accuracy:  0.33511,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72448
# Category, # Members, # Correct Predictions:  0.0, 3300, 2355
# Category, # Members, # Correct Predictions:  0.5, 1278, 525
# Category, # Members, # Correct Predictions:  1.0, 8934, 1648
# Epoch:   27   Train:
#  Average loss:  0.06871,  Accuracy:  0.29366,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71290
# Category, # Members, # Correct Predictions:  0.0, 13335, 11929
# Category, # Members, # Correct Predictions:  0.5, 5171, 1295
# Category, # Members, # Correct Predictions:  1.0, 35539, 2647
# Test:
#  Average loss:  0.10659,  Accuracy:  0.26961,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71570
# Category, # Members, # Correct Predictions:  0.0, 3300, 2680
# Category, # Members, # Correct Predictions:  0.5, 1278, 317
# Category, # Members, # Correct Predictions:  1.0, 8934, 646
# Epoch:   28   Train:
#  Average loss:  0.06980,  Accuracy:  0.28952,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71429
# Category, # Members, # Correct Predictions:  0.0, 13335, 11945
# Category, # Members, # Correct Predictions:  0.5, 5171, 1257
# Category, # Members, # Correct Predictions:  1.0, 35539, 2445
# Test:
#  Average loss:  0.11113,  Accuracy:  0.24674,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.75169
# Category, # Members, # Correct Predictions:  0.0, 3300, 2374
# Category, # Members, # Correct Predictions:  0.5, 1278, 309
# Category, # Members, # Correct Predictions:  1.0, 8934, 651
# Epoch:   29   Train:
#  Average loss:  0.07300,  Accuracy:  0.27386,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71291
# Category, # Members, # Correct Predictions:  0.0, 13335, 12110
# Category, # Members, # Correct Predictions:  0.5, 5171, 837
# Category, # Members, # Correct Predictions:  1.0, 35539, 1854
# Test:
#  Average loss:  0.10150,  Accuracy:  0.25851,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72533
# Category, # Members, # Correct Predictions:  0.0, 3300, 2567
# Category, # Members, # Correct Predictions:  0.5, 1278, 400
# Category, # Members, # Correct Predictions:  1.0, 8934, 526
# Epoch:   30   Train:
#  Average loss:  0.06714,  Accuracy:  0.28225,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71427
# Category, # Members, # Correct Predictions:  0.0, 13335, 11909
# Category, # Members, # Correct Predictions:  0.5, 5171, 1458
# Category, # Members, # Correct Predictions:  1.0, 35539, 1887
# Test:
#  Average loss:  0.10764,  Accuracy:  0.24734,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70059
# Category, # Members, # Correct Predictions:  0.0, 3300, 2927
# Category, # Members, # Correct Predictions:  0.5, 1278, 78
# Category, # Members, # Correct Predictions:  1.0, 8934, 337
# Epoch:   31   Train:
#  Average loss:  0.06679,  Accuracy:  0.27483,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71432
# Category, # Members, # Correct Predictions:  0.0, 13335, 11984
# Category, # Members, # Correct Predictions:  0.5, 5171, 1361
# Category, # Members, # Correct Predictions:  1.0, 35539, 1508
# Test:
#  Average loss:  0.10536,  Accuracy:  0.23905,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72935
# Category, # Members, # Correct Predictions:  0.0, 3300, 2640
# Category, # Members, # Correct Predictions:  0.5, 1278, 229
# Category, # Members, # Correct Predictions:  1.0, 8934, 361
# Epoch:   32   Train:
#  Average loss:  0.06528,  Accuracy:  0.28556,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71350
# Category, # Members, # Correct Predictions:  0.0, 13335, 11921
# Category, # Members, # Correct Predictions:  0.5, 5171, 1592
# Category, # Members, # Correct Predictions:  1.0, 35539, 1920
# Test:
#  Average loss:  0.10786,  Accuracy:  0.23150,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.73236
# Category, # Members, # Correct Predictions:  0.0, 3300, 2533
# Category, # Members, # Correct Predictions:  0.5, 1278, 332
# Category, # Members, # Correct Predictions:  1.0, 8934, 263
# Epoch:   33   Train:
#  Average loss:  0.06671,  Accuracy:  0.29015,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70977
# Category, # Members, # Correct Predictions:  0.0, 13335, 12137
# Category, # Members, # Correct Predictions:  0.5, 5171, 1288
# Category, # Members, # Correct Predictions:  1.0, 35539, 2256
# Test:
#  Average loss:  0.10450,  Accuracy:  0.26510,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71679
# Category, # Members, # Correct Predictions:  0.0, 3300, 2622
# Category, # Members, # Correct Predictions:  0.5, 1278, 395
# Category, # Members, # Correct Predictions:  1.0, 8934, 565
# Epoch:   34   Train:
#  Average loss:  0.06713,  Accuracy:  0.27703,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71682
# Category, # Members, # Correct Predictions:  0.0, 13335, 11877
# Category, # Members, # Correct Predictions:  0.5, 5171, 1395
# Category, # Members, # Correct Predictions:  1.0, 35539, 1700
# Test:
#  Average loss:  0.10342,  Accuracy:  0.27020,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72051
# Category, # Members, # Correct Predictions:  0.0, 3300, 2676
# Category, # Members, # Correct Predictions:  0.5, 1278, 306
# Category, # Members, # Correct Predictions:  1.0, 8934, 669
# Epoch:   35   Train:
#  Average loss:  0.06495,  Accuracy:  0.29361,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71071
# Category, # Members, # Correct Predictions:  0.0, 13335, 12121
# Category, # Members, # Correct Predictions:  0.5, 5171, 1416
# Category, # Members, # Correct Predictions:  1.0, 35539, 2331
# Test:
#  Average loss:  0.11113,  Accuracy:  0.26199,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72701
# Category, # Members, # Correct Predictions:  0.0, 3300, 2506
# Category, # Members, # Correct Predictions:  0.5, 1278, 351
# Category, # Members, # Correct Predictions:  1.0, 8934, 683
# Epoch:   36   Train:
#  Average loss:  0.06810,  Accuracy:  0.28404,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70616
# Category, # Members, # Correct Predictions:  0.0, 13335, 12080
# Category, # Members, # Correct Predictions:  0.5, 5171, 1399
# Category, # Members, # Correct Predictions:  1.0, 35539, 1872
# Test:
#  Average loss:  0.10602,  Accuracy:  0.23290,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.73255
# Category, # Members, # Correct Predictions:  0.0, 3300, 2541
# Category, # Members, # Correct Predictions:  0.5, 1278, 335
# Category, # Members, # Correct Predictions:  1.0, 8934, 271
# Epoch:   37   Train:
#  Average loss:  0.06750,  Accuracy:  0.27701,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71212
# Category, # Members, # Correct Predictions:  0.0, 13335, 11980
# Category, # Members, # Correct Predictions:  0.5, 5171, 1348
# Category, # Members, # Correct Predictions:  1.0, 35539, 1643
# Test:
#  Average loss:  0.10665,  Accuracy:  0.25259,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71730
# Category, # Members, # Correct Predictions:  0.0, 3300, 2671
# Category, # Members, # Correct Predictions:  0.5, 1278, 287
# Category, # Members, # Correct Predictions:  1.0, 8934, 455
# Epoch:   38   Train:
#  Average loss:  0.06719,  Accuracy:  0.29311,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71568
# Category, # Members, # Correct Predictions:  0.0, 13335, 11952
# Category, # Members, # Correct Predictions:  0.5, 5171, 1255
# Category, # Members, # Correct Predictions:  1.0, 35539, 2634
# Test:
#  Average loss:  0.10510,  Accuracy:  0.24689,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.73690
# Category, # Members, # Correct Predictions:  0.0, 3300, 2571
# Category, # Members, # Correct Predictions:  0.5, 1278, 302
# Category, # Members, # Correct Predictions:  1.0, 8934, 463
# Epoch:   39   Train:
#  Average loss:  0.06331,  Accuracy:  0.28245,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71297
# Category, # Members, # Correct Predictions:  0.0, 13335, 12106
# Category, # Members, # Correct Predictions:  0.5, 5171, 1468
# Category, # Members, # Correct Predictions:  1.0, 35539, 1691
# Test:
#  Average loss:  0.10971,  Accuracy:  0.24785,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71056
# Category, # Members, # Correct Predictions:  0.0, 3300, 2799
# Category, # Members, # Correct Predictions:  0.5, 1278, 143
# Category, # Members, # Correct Predictions:  1.0, 8934, 407
# Epoch:   40   Train:
#  Average loss:  0.06505,  Accuracy:  0.27834,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70958
# Category, # Members, # Correct Predictions:  0.0, 13335, 12146
# Category, # Members, # Correct Predictions:  0.5, 5171, 1396
# Category, # Members, # Correct Predictions:  1.0, 35539, 1501
# Test:
#  Average loss:  0.10369,  Accuracy:  0.27043,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70737
# Category, # Members, # Correct Predictions:  0.0, 3300, 2759
# Category, # Members, # Correct Predictions:  0.5, 1278, 311
# Category, # Members, # Correct Predictions:  1.0, 8934, 584
# Epoch:   41   Train:
#  Average loss:  0.06305,  Accuracy:  0.28450,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70942
# Category, # Members, # Correct Predictions:  0.0, 13335, 12187
# Category, # Members, # Correct Predictions:  0.5, 5171, 1413
# Category, # Members, # Correct Predictions:  1.0, 35539, 1776
# Test:
#  Average loss:  0.11005,  Accuracy:  0.25659,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72890
# Category, # Members, # Correct Predictions:  0.0, 3300, 2612
# Category, # Members, # Correct Predictions:  0.5, 1278, 201
# Category, # Members, # Correct Predictions:  1.0, 8934, 654
# Epoch:   42   Train:
#  Average loss:  0.06524,  Accuracy:  0.28543,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71277
# Category, # Members, # Correct Predictions:  0.0, 13335, 12044
# Category, # Members, # Correct Predictions:  0.5, 5171, 1429
# Category, # Members, # Correct Predictions:  1.0, 35539, 1953
# Test:
#  Average loss:  0.10497,  Accuracy:  0.24734,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.73826
# Category, # Members, # Correct Predictions:  0.0, 3300, 2551
# Category, # Members, # Correct Predictions:  0.5, 1278, 335
# Category, # Members, # Correct Predictions:  1.0, 8934, 456
# Epoch:   43   Train:
#  Average loss:  0.06599,  Accuracy:  0.27122,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71312
# Category, # Members, # Correct Predictions:  0.0, 13335, 12039
# Category, # Members, # Correct Predictions:  0.5, 5171, 1310
# Category, # Members, # Correct Predictions:  1.0, 35539, 1309
# Test:
#  Average loss:  0.10989,  Accuracy:  0.25392,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.69507
# Category, # Members, # Correct Predictions:  0.0, 3300, 2743
# Category, # Members, # Correct Predictions:  0.5, 1278, 335
# Category, # Members, # Correct Predictions:  1.0, 8934, 353
# Epoch:   44   Train:
#  Average loss:  0.06604,  Accuracy:  0.27753,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70795
# Category, # Members, # Correct Predictions:  0.0, 13335, 12195
# Category, # Members, # Correct Predictions:  0.5, 5171, 1324
# Category, # Members, # Correct Predictions:  1.0, 35539, 1480
# Test:
#  Average loss:  0.10764,  Accuracy:  0.22839,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.74288
# Category, # Members, # Correct Predictions:  0.0, 3300, 2467
# Category, # Members, # Correct Predictions:  0.5, 1278, 308
# Category, # Members, # Correct Predictions:  1.0, 8934, 311
# Epoch:   45   Train:
#  Average loss:  0.06482,  Accuracy:  0.29007,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71437
# Category, # Members, # Correct Predictions:  0.0, 13335, 11851
# Category, # Members, # Correct Predictions:  0.5, 5171, 1633
# Category, # Members, # Correct Predictions:  1.0, 35539, 2193
# Test:
#  Average loss:  0.10646,  Accuracy:  0.24489,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72527
# Category, # Members, # Correct Predictions:  0.0, 3300, 2558
# Category, # Members, # Correct Predictions:  0.5, 1278, 331
# Category, # Members, # Correct Predictions:  1.0, 8934, 420
# Epoch:   46   Train:
#  Average loss:  0.06222,  Accuracy:  0.29011,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71310
# Category, # Members, # Correct Predictions:  0.0, 13335, 11916
# Category, # Members, # Correct Predictions:  0.5, 5171, 1731
# Category, # Members, # Correct Predictions:  1.0, 35539, 2032
# Test:
#  Average loss:  0.10204,  Accuracy:  0.26414,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71647
# Category, # Members, # Correct Predictions:  0.0, 3300, 2603
# Category, # Members, # Correct Predictions:  0.5, 1278, 407
# Category, # Members, # Correct Predictions:  1.0, 8934, 559
# Epoch:   47   Train:
#  Average loss:  0.06299,  Accuracy:  0.27723,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71462
# Category, # Members, # Correct Predictions:  0.0, 13335, 12021
# Category, # Members, # Correct Predictions:  0.5, 5171, 1482
# Category, # Members, # Correct Predictions:  1.0, 35539, 1480
# Test:
#  Average loss:  0.11030,  Accuracy:  0.30699,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72791
# Category, # Members, # Correct Predictions:  0.0, 3300, 2471
# Category, # Members, # Correct Predictions:  0.5, 1278, 351
# Category, # Members, # Correct Predictions:  1.0, 8934, 1326
# Epoch:   48   Train:
#  Average loss:  0.06823,  Accuracy:  0.27520,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70852
# Category, # Members, # Correct Predictions:  0.0, 13335, 12163
# Category, # Members, # Correct Predictions:  0.5, 5171, 1155
# Category, # Members, # Correct Predictions:  1.0, 35539, 1555
# Test:
#  Average loss:  0.11052,  Accuracy:  0.23446,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.77018
# Category, # Members, # Correct Predictions:  0.0, 3300, 2425
# Category, # Members, # Correct Predictions:  0.5, 1278, 184
# Category, # Members, # Correct Predictions:  1.0, 8934, 559
# Epoch:   49   Train:
#  Average loss:  0.06586,  Accuracy:  0.27250,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71145
# Category, # Members, # Correct Predictions:  0.0, 13335, 12041
# Category, # Members, # Correct Predictions:  0.5, 5171, 1325
# Category, # Members, # Correct Predictions:  1.0, 35539, 1361
# Test:
#  Average loss:  0.10601,  Accuracy:  0.23342,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72586
# Category, # Members, # Correct Predictions:  0.0, 3300, 2633
# Category, # Members, # Correct Predictions:  0.5, 1278, 258
# Category, # Members, # Correct Predictions:  1.0, 8934, 263
# Epoch:   50   Train:
#  Average loss:  0.06221,  Accuracy:  0.28265,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71072
# Category, # Members, # Correct Predictions:  0.0, 13335, 12108
# Category, # Members, # Correct Predictions:  0.5, 5171, 1575
# Category, # Members, # Correct Predictions:  1.0, 35539, 1593
# Test:
#  Average loss:  0.10643,  Accuracy:  0.26636,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.73308
# Category, # Members, # Correct Predictions:  0.0, 3300, 2482
# Category, # Members, # Correct Predictions:  0.5, 1278, 419
# Category, # Members, # Correct Predictions:  1.0, 8934, 698
# Epoch:   51   Train:
#  Average loss:  0.06271,  Accuracy:  0.29133,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71026
# Category, # Members, # Correct Predictions:  0.0, 13335, 12124
# Category, # Members, # Correct Predictions:  0.5, 5171, 1564
# Category, # Members, # Correct Predictions:  1.0, 35539, 2057
# Test:
#  Average loss:  0.10501,  Accuracy:  0.30610,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72493
# Category, # Members, # Correct Predictions:  0.0, 3300, 2553
# Category, # Members, # Correct Predictions:  0.5, 1278, 425
# Category, # Members, # Correct Predictions:  1.0, 8934, 1158
# Epoch:   52   Train:
#  Average loss:  0.06155,  Accuracy:  0.28733,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70959
# Category, # Members, # Correct Predictions:  0.0, 13335, 12156
# Category, # Members, # Correct Predictions:  0.5, 5171, 1580
# Category, # Members, # Correct Predictions:  1.0, 35539, 1793
# Test:
#  Average loss:  0.10215,  Accuracy:  0.26458,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71800
# Category, # Members, # Correct Predictions:  0.0, 3300, 2604
# Category, # Members, # Correct Predictions:  0.5, 1278, 417
# Category, # Members, # Correct Predictions:  1.0, 8934, 554
# Epoch:   53   Train:
#  Average loss:  0.06029,  Accuracy:  0.29427,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.70943
# Category, # Members, # Correct Predictions:  0.0, 13335, 12194
# Category, # Members, # Correct Predictions:  0.5, 5171, 1744
# Category, # Members, # Correct Predictions:  1.0, 35539, 1966
# Test:
#  Average loss:  0.10514,  Accuracy:  0.23179,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.73196
# Category, # Members, # Correct Predictions:  0.0, 3300, 2681
# Category, # Members, # Correct Predictions:  0.5, 1278, 194
# Category, # Members, # Correct Predictions:  1.0, 8934, 257
# Epoch:   54   Train:
#  Average loss:  0.06100,  Accuracy:  0.28852,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71036
# Category, # Members, # Correct Predictions:  0.0, 13335, 12315
# Category, # Members, # Correct Predictions:  0.5, 5171, 1289
# Category, # Members, # Correct Predictions:  1.0, 35539, 1989
# Test:
#  Average loss:  0.10503,  Accuracy:  0.25414,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.73006
# Category, # Members, # Correct Predictions:  0.0, 3300, 2566
# Category, # Members, # Correct Predictions:  0.5, 1278, 335
# Category, # Members, # Correct Predictions:  1.0, 8934, 533
# Epoch:   55   Train:
#  Average loss:  0.06039,  Accuracy:  0.29831,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71152
# Category, # Members, # Correct Predictions:  0.0, 13335, 12114
# Category, # Members, # Correct Predictions:  0.5, 5171, 1684
# Category, # Members, # Correct Predictions:  1.0, 35539, 2324
# Test:
#  Average loss:  0.10698,  Accuracy:  0.25903,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.73361
# Category, # Members, # Correct Predictions:  0.0, 3300, 2529
# Category, # Members, # Correct Predictions:  0.5, 1278, 373
# Category, # Members, # Correct Predictions:  1.0, 8934, 598
# Epoch:   56   Train:
#  Average loss:  0.35665,  Accuracy:  0.26178,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.38487
# Category, # Members, # Correct Predictions:  0.0, 13335, 12726
# Category, # Members, # Correct Predictions:  0.5, 5171, 763
# Category, # Members, # Correct Predictions:  1.0, 35539, 659
# Test:
#  Average loss:  0.70848,  Accuracy:  0.24423,  Smallest:  0.00000,  Largest:  0.00002,  Average:  0.00000
# Category, # Members, # Correct Predictions:  0.0, 3300, 3300
# Category, # Members, # Correct Predictions:  0.5, 1278, 0
# Category, # Members, # Correct Predictions:  1.0, 8934, 0
# Epoch:   57   Train:
#  Average loss:  0.09070,  Accuracy:  0.27943,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.68005
# Category, # Members, # Correct Predictions:  0.0, 13335, 12249
# Category, # Members, # Correct Predictions:  0.5, 5171, 1317
# Category, # Members, # Correct Predictions:  1.0, 35539, 1536
# Test:
#  Average loss:  0.10802,  Accuracy:  0.24956,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.74046
# Category, # Members, # Correct Predictions:  0.0, 3300, 2449
# Category, # Members, # Correct Predictions:  0.5, 1278, 345
# Category, # Members, # Correct Predictions:  1.0, 8934, 578
# Epoch:   58   Train:
#  Average loss:  0.06029,  Accuracy:  0.29651,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.71352
# Category, # Members, # Correct Predictions:  0.0, 13335, 12134
# Category, # Members, # Correct Predictions:  0.5, 5171, 1538
# Category, # Members, # Correct Predictions:  1.0, 35539, 2353
# Test:
#  Average loss:  0.10663,  Accuracy:  0.29115,  Smallest:  0.00000,  Largest:  1.00000,  Average:  0.72039
# Category, # Members, # Correct Predictions:  0.0, 3300, 2517
# Category, # Members, # Correct Predictions:  0.5, 1278, 417
# Category, # Members, # Correct Predictions:  1.0, 8934, 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# ~/miniconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
plotter.fig
