# %%
# %matplotlib inline
from src.connect4 import train

import numpy as np
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data

from sklearn.model_selection import train_test_split


torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.manual_seed(999)
np.random.seed(0)

# %%
channels = 2
filters = 64

n_epocs = 10000
batch_size = 512
test_size = 0.2
learning_rate = 0.0002 * (batch_size / 1024.0)
momentum = 0.0

# %%
class Connect4Dataset(data.Dataset):
    def __init__(self, boards, values):
        assert len(boards) == len(values)
        self.boards = boards
        self.values = values
        
    def __len__(self):
        return len(self.boards)
    
    def __getitem__(self, idx):
        return self.boards[idx], self.values[idx]

boards = torch.load('/home/richard/Downloads/connect4_boards.pth').numpy()
values = torch.load('/home/richard/Downloads/connect4_values.pth').numpy()

# Here we don't want to have the player to move channel
boards = boards[:, 3 - channels:]

board_train, board_test, value_train, value_test = train_test_split(boards, values, test_size=test_size, shuffle=True)

# %%
# augment data
v_wins = value_train[value_train == 1.0]
v_draws = value_train[value_train == 0.5]
v_losses = value_train[value_train == 0.0]
b_wins = board_train[value_train == 1.0]
b_draws = board_train[value_train == 0.5]
b_losses = board_train[value_train == 0.0]

n_wins = len(v_wins)
n_draws = len(v_draws)
n_losses = len(v_losses)

v_augmented_draws = np.repeat(v_draws, n_wins/n_draws)
v_augmented_losses = np.repeat(v_losses, n_wins/n_losses)
b_augmented_draws = np.repeat(b_draws, n_wins/n_draws, axis=0)
b_augmented_losses = np.repeat(b_losses, n_wins/n_losses, axis=0)

extra_draw_idx = np.random.choice(range(len(v_draws)), n_wins - len(v_augmented_draws), replace=False)
extra_losses_idx = np.random.choice(range(len(v_losses)), n_wins - len(v_augmented_losses), replace=False)

v_augmented_draws = np.hstack([v_augmented_draws, v_draws[extra_draw_idx]])
v_augmented_losses = np.hstack([v_augmented_losses, v_losses[extra_losses_idx]])
b_augmented_draws = np.concatenate([b_augmented_draws, b_draws[extra_draw_idx]], axis=0)
b_augmented_losses = np.concatenate([b_augmented_losses, b_losses[extra_losses_idx]], axis=0)

value_train = np.hstack([v_wins, v_augmented_draws, v_augmented_losses])
board_train = np.concatenate([b_wins, b_augmented_draws, b_augmented_losses], axis=0)

# np.random.shuffle(value_train)
# np.random.shuffle(board_train)

print(len(value_train), len(board_train))

train = Connect4Dataset(torch.from_numpy(board_train), torch.from_numpy(value_train))
test = Connect4Dataset(torch.from_numpy(board_test), torch.from_numpy(value_test))

train_gen = data.DataLoader(train, batch_size, shuffle=False)
test_gen = data.DataLoader(test, batch_size, shuffle=False)
# Out:
# 106617 106617

# %%
from src.connect4.utils import Connect4Stats as info

# Input with N * channels * (6,7)
# Output with N * filters * (6,7)
convolutional_layer = \
    nn.Sequential(nn.Conv2d(in_channels=channels,
                            out_channels=filters,
                            kernel_size=3,
                            stride=1,
                            padding=1,
                            dilation=1,
                            groups=1,
                            bias=False),
                  nn.BatchNorm2d(filters),
                  nn.LeakyReLU())

# Input with N * filters * (6,7)
# Output with N * filters * (6,7)
class ResidualLayer(nn.Module):
    def __init__(self):
        super(ResidualLayer, self).__init__()
        self.conv1 = nn.Conv2d(filters, filters, 3, padding=1, bias=False)
        self.conv2 = nn.Conv2d(filters, filters, 3, padding=1, bias=False)
        self.batch_norm1 = nn.BatchNorm2d(filters)
        self.batch_norm2 = nn.BatchNorm2d(filters)
        self.relu = nn.LeakyReLU()

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.batch_norm1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.batch_norm2(out)

        out += residual
        out = self.relu(out)
        return out


# Input with N * filters * (6,7)
# Output with N * 1 * 1
class ValueHead(nn.Module):
    def __init__(self):
        super(ValueHead, self).__init__()
        self.conv1 = nn.Conv2d(filters, 1, 1)
        self.batch_norm = nn.BatchNorm2d(1)
        self.relu = nn.LeakyReLU()
        self.fcN = nn.Sequential(*[nn.Linear(info.area, info.area) for _ in range(4)])
        self.fc2 = nn.Linear(info.area, 1)
        self.tanh = torch.nn.Tanh()
        self.w1 = nn.Parameter(torch.tensor(1.0), requires_grad=False)
        self.w2 = nn.Parameter(torch.tensor(0.5), requires_grad=False)

    def forward(self, x):
        x = self.conv1(x)
        x = self.batch_norm(x)
        x = self.relu(x)
        x = x.view(x.shape[0], 1, -1)
        x = self.fcN(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.tanh(x)
#         map from [-1, 1] to [0, 1]
        x = (x + self.w1) * self.w2
        x = x.view(-1, 1)
        return x

def init_normal(m):
    if type(m) == nn.Linear:
        nn.init.normal_(m.weight, std=0.002)
    elif type(m) == nn.Conv2d:
        nn.init.normal_(m.weight, std=0.002)
    elif type(m) == nn.BatchNorm2d:
        nn.init.normal_(m.weight, std=0.002)
#         nn.init.constant_(m.bias, 0)

net = nn.Sequential(convolutional_layer,
                    nn.Sequential(*[ResidualLayer() for _ in range(4)]),
                    ValueHead())

# net.apply(init_normal)

# net = convolutional_layer
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(2, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (1): Sequential(
#     (0): ResidualLayer(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.01)
#     )
#     (1): ResidualLayer(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.01)
#     )
#     (2): ResidualLayer(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.01)
#     )
#     (3): ResidualLayer(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (batch_norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (2): ValueHead(
#     (conv1): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#     (batch_norm): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): LeakyReLU(negative_slope=0.01)
#     (fcN): Sequential(
#       (0): Linear(in_features=42, out_features=42, bias=True)
#       (1): Linear(in_features=42, out_features=42, bias=True)
#       (2): Linear(in_features=42, out_features=42, bias=True)
#       (3): Linear(in_features=42, out_features=42, bias=True)
#     )
#     (fc2): Linear(in_features=42, out_features=1, bias=True)
#     (tanh): Tanh()
#   )
# )

# %%
# criterion = nn.MSELoss()
criterion = nn.L1Loss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum)
# optimizer = optim.Adam(net.parameters(), lr=learning_rate)

# %%
def categorise_predictions(preds):
    preds = preds * 3.0
    torch.floor_(preds)
    preds = preds / 2.0
    return preds

class Stats():
    def __init__(self):
        self.n = 0
        self.average_value = 0.0
        self.loss = 0.0
        self.smallest = 1.0
        self.largest = 0.0
        self.correct = {i : 0 for i in [0.0, 0.5, 1.0]}
        self.total = {i : 0 for i in [0.0, 0.5, 1.0]}
        
    def __repr__(self):
        x = "Average loss:  " + "{:.5f}".format(self.loss / self.n) + \
            ",  Smallest:  " + "{:.5f}".format(self.smallest) + \
            ",  Largest:  " + "{:.5f}".format(self.largest) + \
            ",  Average:  " + "{:.5f}".format(self.average_value / self.n)
        
        for k in self.correct:
            x += "\nCategory, # Predictions, # Correct:  {}, {}, {}".format(
                k,
                self.total[k],
                self.correct[k])
        return x

def update_stats(stats: Stats, outputs, values, loss):
    stats.n += len(values)
    stats.average_value += outputs.sum().item()
    stats.loss += loss.item() * len(values)
    stats.smallest = min(stats.smallest, torch.min(outputs).item())
    stats.largest = max(stats.largest, torch.max(outputs).item())
            
    categories = categorise_predictions(outputs)
    values = values.view(-1)
    categories = categories.view(-1)

    for k in stats.correct:
        idx = (values == k).nonzero()
        stats.total[k] += len(idx)
        stats.correct[k] += len(torch.eq(categories[idx], values[idx]).nonzero()) 

    return stats

# %%
# %%time

for epoch in range(n_epocs):
    
    net = net.train()
    train_stats = Stats()
    test_stats = Stats()
    
    for board, value in train_gen:
        board, value = board.to(device), value.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        output = net(board)
        loss = criterion(output, value)
        loss.backward()
        optimizer.step()
        
        train_stats = update_stats(train_stats, output, value, loss)

    # validate
    with torch.set_grad_enabled(False):
        net = net.eval()
        for board, value in test_gen:
            board, value = board.to(device), value.to(device)

            output = net(board)
            loss = criterion(output, value)
            
            test_stats = update_stats(test_stats, output, value, loss)
            
    print("Epoch:  ", epoch, "  Train:\n", train_stats, "\nTest:\n", test_stats)
            

print('Finished Training')
# Out:
# Train:
#  Average loss:  0.34150,  Smallest:  0.42234,  Largest:  0.55620,  Average:  0.47951
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.46389,  Smallest:  0.42018,  Largest:  0.53730,  Average:  0.47834
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.34031,  Smallest:  0.42603,  Largest:  0.56021,  Average:  0.48333
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.46215,  Smallest:  0.42355,  Largest:  0.54104,  Average:  0.48186
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33940,  Smallest:  0.42920,  Largest:  0.56321,  Average:  0.48649
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.46075,  Smallest:  0.42648,  Largest:  0.54407,  Average:  0.48475
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33871,  Smallest:  0.43186,  Largest:  0.56549,  Average:  0.48906
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45963,  Smallest:  0.42906,  Largest:  0.54646,  Average:  0.48709
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33818,  Smallest:  0.43408,  Largest:  0.56721,  Average:  0.49112
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45876,  Smallest:  0.43137,  Largest:  0.54802,  Average:  0.48895
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33777,  Smallest:  0.43589,  Largest:  0.56849,  Average:  0.49273
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45807,  Smallest:  0.43351,  Largest:  0.54908,  Average:  0.49041
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33746,  Smallest:  0.43739,  Largest:  0.56939,  Average:  0.49400
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45753,  Smallest:  0.43541,  Largest:  0.54978,  Average:  0.49157
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33719,  Smallest:  0.43863,  Largest:  0.56998,  Average:  0.49498
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45712,  Smallest:  0.43707,  Largest:  0.55017,  Average:  0.49247
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33698,  Smallest:  0.43966,  Largest:  0.57035,  Average:  0.49574
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45679,  Smallest:  0.43852,  Largest:  0.55035,  Average:  0.49318
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33679,  Smallest:  0.44053,  Largest:  0.57054,  Average:  0.49633
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45654,  Smallest:  0.43915,  Largest:  0.55036,  Average:  0.49372
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33663,  Smallest:  0.44123,  Largest:  0.57060,  Average:  0.49676
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45635,  Smallest:  0.43967,  Largest:  0.55028,  Average:  0.49413
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33648,  Smallest:  0.44182,  Largest:  0.57055,  Average:  0.49708
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45621,  Smallest:  0.44010,  Largest:  0.55016,  Average:  0.49443
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33635,  Smallest:  0.44231,  Largest:  0.57041,  Average:  0.49731
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45610,  Smallest:  0.44047,  Largest:  0.54996,  Average:  0.49466
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33623,  Smallest:  0.44273,  Largest:  0.57021,  Average:  0.49747
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45602,  Smallest:  0.44079,  Largest:  0.54970,  Average:  0.49483
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33610,  Smallest:  0.44308,  Largest:  0.56994,  Average:  0.49757
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45597,  Smallest:  0.44106,  Largest:  0.54937,  Average:  0.49493
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33600,  Smallest:  0.44338,  Largest:  0.56966,  Average:  0.49763
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45592,  Smallest:  0.44131,  Largest:  0.54905,  Average:  0.49501
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33590,  Smallest:  0.44366,  Largest:  0.56937,  Average:  0.49767
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45589,  Smallest:  0.44154,  Largest:  0.54892,  Average:  0.49508
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33581,  Smallest:  0.44390,  Largest:  0.56908,  Average:  0.49769
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45586,  Smallest:  0.44177,  Largest:  0.54882,  Average:  0.49513
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33573,  Smallest:  0.44414,  Largest:  0.56880,  Average:  0.49772
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45583,  Smallest:  0.44200,  Largest:  0.54872,  Average:  0.49519
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33564,  Smallest:  0.44437,  Largest:  0.56851,  Average:  0.49774
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45580,  Smallest:  0.44223,  Largest:  0.54861,  Average:  0.49525
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33556,  Smallest:  0.44460,  Largest:  0.56824,  Average:  0.49777
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45577,  Smallest:  0.44244,  Largest:  0.54851,  Average:  0.49531
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33548,  Smallest:  0.44481,  Largest:  0.56796,  Average:  0.49779
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45574,  Smallest:  0.44265,  Largest:  0.54841,  Average:  0.49536
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33540,  Smallest:  0.44502,  Largest:  0.56769,  Average:  0.49781
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45571,  Smallest:  0.44284,  Largest:  0.54831,  Average:  0.49541
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33532,  Smallest:  0.44521,  Largest:  0.56745,  Average:  0.49784
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45568,  Smallest:  0.44304,  Largest:  0.54823,  Average:  0.49548
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33525,  Smallest:  0.44542,  Largest:  0.56720,  Average:  0.49787
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45565,  Smallest:  0.44323,  Largest:  0.54815,  Average:  0.49554
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33517,  Smallest:  0.44561,  Largest:  0.56694,  Average:  0.49789
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45563,  Smallest:  0.44341,  Largest:  0.54806,  Average:  0.49558
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33509,  Smallest:  0.44579,  Largest:  0.56670,  Average:  0.49790
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45560,  Smallest:  0.44358,  Largest:  0.54799,  Average:  0.49562
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33502,  Smallest:  0.44596,  Largest:  0.56643,  Average:  0.49791
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45559,  Smallest:  0.44373,  Largest:  0.54790,  Average:  0.49565
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33495,  Smallest:  0.44612,  Largest:  0.56617,  Average:  0.49791
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45557,  Smallest:  0.44389,  Largest:  0.54784,  Average:  0.49568
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33489,  Smallest:  0.44628,  Largest:  0.56592,  Average:  0.49792
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45555,  Smallest:  0.44405,  Largest:  0.54779,  Average:  0.49572
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33482,  Smallest:  0.44645,  Largest:  0.56568,  Average:  0.49792
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45554,  Smallest:  0.44420,  Largest:  0.54775,  Average:  0.49575
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33476,  Smallest:  0.44661,  Largest:  0.56544,  Average:  0.49794
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45551,  Smallest:  0.44436,  Largest:  0.54773,  Average:  0.49579
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33470,  Smallest:  0.44681,  Largest:  0.56523,  Average:  0.49796
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45549,  Smallest:  0.44452,  Largest:  0.54774,  Average:  0.49585
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33464,  Smallest:  0.44700,  Largest:  0.56501,  Average:  0.49799
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45546,  Smallest:  0.44467,  Largest:  0.54774,  Average:  0.49590
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33458,  Smallest:  0.44719,  Largest:  0.56480,  Average:  0.49800
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45544,  Smallest:  0.44480,  Largest:  0.54772,  Average:  0.49593
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33452,  Smallest:  0.44737,  Largest:  0.56458,  Average:  0.49801
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45543,  Smallest:  0.44493,  Largest:  0.54771,  Average:  0.49596
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33447,  Smallest:  0.44753,  Largest:  0.56438,  Average:  0.49802
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45541,  Smallest:  0.44506,  Largest:  0.54771,  Average:  0.49600
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33441,  Smallest:  0.44770,  Largest:  0.56419,  Average:  0.49803
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45540,  Smallest:  0.44518,  Largest:  0.54772,  Average:  0.49603
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33436,  Smallest:  0.44785,  Largest:  0.56399,  Average:  0.49804
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45538,  Smallest:  0.44531,  Largest:  0.54773,  Average:  0.49607
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33430,  Smallest:  0.44800,  Largest:  0.56380,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45537,  Smallest:  0.44543,  Largest:  0.54775,  Average:  0.49610
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33425,  Smallest:  0.44814,  Largest:  0.56362,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45535,  Smallest:  0.44555,  Largest:  0.54778,  Average:  0.49613
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33420,  Smallest:  0.44827,  Largest:  0.56344,  Average:  0.49806
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45534,  Smallest:  0.44567,  Largest:  0.54781,  Average:  0.49616
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33414,  Smallest:  0.44840,  Largest:  0.56325,  Average:  0.49807
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45533,  Smallest:  0.44577,  Largest:  0.54783,  Average:  0.49618
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33409,  Smallest:  0.44851,  Largest:  0.56304,  Average:  0.49806
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45532,  Smallest:  0.44587,  Largest:  0.54786,  Average:  0.49620
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33405,  Smallest:  0.44862,  Largest:  0.56284,  Average:  0.49806
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45531,  Smallest:  0.44597,  Largest:  0.54789,  Average:  0.49622
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33400,  Smallest:  0.44873,  Largest:  0.56264,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45530,  Smallest:  0.44607,  Largest:  0.54794,  Average:  0.49624
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33395,  Smallest:  0.44884,  Largest:  0.56244,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45530,  Smallest:  0.44616,  Largest:  0.54797,  Average:  0.49625
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33391,  Smallest:  0.44894,  Largest:  0.56226,  Average:  0.49804
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45529,  Smallest:  0.44626,  Largest:  0.54803,  Average:  0.49628
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33387,  Smallest:  0.44904,  Largest:  0.56209,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45527,  Smallest:  0.44637,  Largest:  0.54810,  Average:  0.49632
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33382,  Smallest:  0.44915,  Largest:  0.56194,  Average:  0.49808
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45525,  Smallest:  0.44647,  Largest:  0.54819,  Average:  0.49637
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33377,  Smallest:  0.44926,  Largest:  0.56178,  Average:  0.49809
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45523,  Smallest:  0.44657,  Largest:  0.54826,  Average:  0.49640
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33373,  Smallest:  0.44936,  Largest:  0.56161,  Average:  0.49810
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45522,  Smallest:  0.44665,  Largest:  0.54833,  Average:  0.49642
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33368,  Smallest:  0.44944,  Largest:  0.56144,  Average:  0.49810
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45522,  Smallest:  0.44672,  Largest:  0.54839,  Average:  0.49644
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33364,  Smallest:  0.44951,  Largest:  0.56127,  Average:  0.49809
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45521,  Smallest:  0.44679,  Largest:  0.54845,  Average:  0.49646
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33359,  Smallest:  0.44952,  Largest:  0.56111,  Average:  0.49809
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45521,  Smallest:  0.44685,  Largest:  0.54852,  Average:  0.49647
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33355,  Smallest:  0.44941,  Largest:  0.56094,  Average:  0.49808
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45520,  Smallest:  0.44690,  Largest:  0.54858,  Average:  0.49648
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33351,  Smallest:  0.44931,  Largest:  0.56078,  Average:  0.49806
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45520,  Smallest:  0.44695,  Largest:  0.54864,  Average:  0.49649
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33346,  Smallest:  0.44918,  Largest:  0.56063,  Average:  0.49806
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45520,  Smallest:  0.44700,  Largest:  0.54871,  Average:  0.49650
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33342,  Smallest:  0.44905,  Largest:  0.56048,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45519,  Smallest:  0.44705,  Largest:  0.54879,  Average:  0.49652
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33338,  Smallest:  0.44892,  Largest:  0.56036,  Average:  0.49804
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45519,  Smallest:  0.44709,  Largest:  0.54888,  Average:  0.49653
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33335,  Smallest:  0.44878,  Largest:  0.56024,  Average:  0.49804
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45518,  Smallest:  0.44713,  Largest:  0.54897,  Average:  0.49656
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33331,  Smallest:  0.44865,  Largest:  0.56014,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45517,  Smallest:  0.44718,  Largest:  0.54909,  Average:  0.49659
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33327,  Smallest:  0.44852,  Largest:  0.56003,  Average:  0.49806
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45516,  Smallest:  0.44722,  Largest:  0.54920,  Average:  0.49662
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33323,  Smallest:  0.44837,  Largest:  0.55993,  Average:  0.49806
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45515,  Smallest:  0.44726,  Largest:  0.54931,  Average:  0.49664
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33319,  Smallest:  0.44822,  Largest:  0.55985,  Average:  0.49807
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45514,  Smallest:  0.44730,  Largest:  0.54943,  Average:  0.49667
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33315,  Smallest:  0.44807,  Largest:  0.55976,  Average:  0.49807
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45513,  Smallest:  0.44733,  Largest:  0.54955,  Average:  0.49669
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33312,  Smallest:  0.44793,  Largest:  0.55969,  Average:  0.49807
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45512,  Smallest:  0.44737,  Largest:  0.54968,  Average:  0.49672
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33307,  Smallest:  0.44777,  Largest:  0.55962,  Average:  0.49808
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45511,  Smallest:  0.44740,  Largest:  0.54980,  Average:  0.49674
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33304,  Smallest:  0.44761,  Largest:  0.55954,  Average:  0.49808
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45510,  Smallest:  0.44742,  Largest:  0.54994,  Average:  0.49677
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33300,  Smallest:  0.44745,  Largest:  0.55947,  Average:  0.49809
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45510,  Smallest:  0.44745,  Largest:  0.55007,  Average:  0.49679
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33296,  Smallest:  0.44728,  Largest:  0.55939,  Average:  0.49809
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45509,  Smallest:  0.44746,  Largest:  0.55020,  Average:  0.49681
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33292,  Smallest:  0.44711,  Largest:  0.55932,  Average:  0.49809
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45509,  Smallest:  0.44747,  Largest:  0.55034,  Average:  0.49683
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33288,  Smallest:  0.44693,  Largest:  0.55924,  Average:  0.49809
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45508,  Smallest:  0.44748,  Largest:  0.55047,  Average:  0.49685
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33285,  Smallest:  0.44676,  Largest:  0.55918,  Average:  0.49810
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45507,  Smallest:  0.44748,  Largest:  0.55063,  Average:  0.49688
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33281,  Smallest:  0.44658,  Largest:  0.55912,  Average:  0.49811
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45506,  Smallest:  0.44749,  Largest:  0.55079,  Average:  0.49691
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33277,  Smallest:  0.44638,  Largest:  0.55905,  Average:  0.49811
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45506,  Smallest:  0.44748,  Largest:  0.55093,  Average:  0.49693
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33274,  Smallest:  0.44619,  Largest:  0.55899,  Average:  0.49811
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45505,  Smallest:  0.44747,  Largest:  0.55109,  Average:  0.49695
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33270,  Smallest:  0.44600,  Largest:  0.55893,  Average:  0.49811
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45504,  Smallest:  0.44730,  Largest:  0.55125,  Average:  0.49698
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33266,  Smallest:  0.44581,  Largest:  0.55888,  Average:  0.49812
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45504,  Smallest:  0.44710,  Largest:  0.55141,  Average:  0.49700
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33262,  Smallest:  0.44554,  Largest:  0.55881,  Average:  0.49812
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45504,  Smallest:  0.44690,  Largest:  0.55157,  Average:  0.49702
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33259,  Smallest:  0.44524,  Largest:  0.55877,  Average:  0.49811
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45503,  Smallest:  0.44670,  Largest:  0.55175,  Average:  0.49704
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33255,  Smallest:  0.44492,  Largest:  0.55871,  Average:  0.49812
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45503,  Smallest:  0.44650,  Largest:  0.55192,  Average:  0.49706
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33251,  Smallest:  0.44461,  Largest:  0.55866,  Average:  0.49811
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45502,  Smallest:  0.44629,  Largest:  0.55210,  Average:  0.49707
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33247,  Smallest:  0.44427,  Largest:  0.55859,  Average:  0.49810
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45502,  Smallest:  0.44608,  Largest:  0.55228,  Average:  0.49708
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33243,  Smallest:  0.44393,  Largest:  0.55852,  Average:  0.49809
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45503,  Smallest:  0.44586,  Largest:  0.55245,  Average:  0.49709
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33240,  Smallest:  0.44358,  Largest:  0.55847,  Average:  0.49808
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45503,  Smallest:  0.44563,  Largest:  0.55263,  Average:  0.49710
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33236,  Smallest:  0.44323,  Largest:  0.55842,  Average:  0.49807
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45503,  Smallest:  0.44541,  Largest:  0.55279,  Average:  0.49711
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33232,  Smallest:  0.44288,  Largest:  0.55834,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45503,  Smallest:  0.44517,  Largest:  0.55295,  Average:  0.49712
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33229,  Smallest:  0.44255,  Largest:  0.55828,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45502,  Smallest:  0.44495,  Largest:  0.55314,  Average:  0.49714
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33225,  Smallest:  0.44220,  Largest:  0.55821,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45502,  Smallest:  0.44472,  Largest:  0.55332,  Average:  0.49715
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33221,  Smallest:  0.44185,  Largest:  0.55815,  Average:  0.49805
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45502,  Smallest:  0.44449,  Largest:  0.55351,  Average:  0.49717
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33217,  Smallest:  0.44150,  Largest:  0.55834,  Average:  0.49804
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45502,  Smallest:  0.44425,  Largest:  0.55371,  Average:  0.49719
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33213,  Smallest:  0.44114,  Largest:  0.55880,  Average:  0.49804
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45501,  Smallest:  0.44400,  Largest:  0.55390,  Average:  0.49721
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33209,  Smallest:  0.44077,  Largest:  0.55926,  Average:  0.49803
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45501,  Smallest:  0.44375,  Largest:  0.55409,  Average:  0.49722
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33206,  Smallest:  0.44040,  Largest:  0.55972,  Average:  0.49803
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45501,  Smallest:  0.44350,  Largest:  0.55429,  Average:  0.49724
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33201,  Smallest:  0.44001,  Largest:  0.56019,  Average:  0.49803
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45501,  Smallest:  0.44324,  Largest:  0.55448,  Average:  0.49725
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
#  Average loss:  0.33197,  Smallest:  0.43963,  Largest:  0.56065,  Average:  0.49802
# Category, # Predictions, # Correct:  0.0, 35539, 0
# Category, # Predictions, # Correct:  0.5, 35539, 35539
# Category, # Predictions, # Correct:  1.0, 35539, 0
# Test:
#  Average loss:  0.45501,  Smallest:  0.44298,  Largest:  0.55469,  Average:  0.49727
# Category, # Predictions, # Correct:  0.0, 3300, 0
# Category, # Predictions, # Correct:  0.5, 1278, 1278
# Category, # Predictions, # Correct:  1.0, 8934, 0
# Train:
# ...
# Category, # Predictions, # Correct:  0.5, 35539, 32769
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69526,  Smallest:  0.00087,  Largest:  0.79255,  Average:  0.02584
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03291,  Smallest:  0.00059,  Largest:  0.99951,  Average:  0.50222
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 32905
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69543,  Smallest:  0.00086,  Largest:  0.79007,  Average:  0.02551
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03289,  Smallest:  0.00059,  Largest:  0.99952,  Average:  0.50182
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 32880
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69541,  Smallest:  0.00086,  Largest:  0.79205,  Average:  0.02554
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03347,  Smallest:  0.00058,  Largest:  0.99952,  Average:  0.50240
# Category, # Predictions, # Correct:  0.0, 35539, 35505
# Category, # Predictions, # Correct:  0.5, 35539, 32948
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69538,  Smallest:  0.00087,  Largest:  0.78883,  Average:  0.02561
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03290,  Smallest:  0.00055,  Largest:  0.99952,  Average:  0.50158
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33025
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69527,  Smallest:  0.00086,  Largest:  0.78775,  Average:  0.02582
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03282,  Smallest:  0.00056,  Largest:  0.99953,  Average:  0.50264
# Category, # Predictions, # Correct:  0.0, 35539, 35503
# Category, # Predictions, # Correct:  0.5, 35539, 32852
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69539,  Smallest:  0.00087,  Largest:  0.79355,  Average:  0.02560
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03231,  Smallest:  0.00055,  Largest:  0.99954,  Average:  0.50373
# Category, # Predictions, # Correct:  0.0, 35539, 35503
# Category, # Predictions, # Correct:  0.5, 35539, 33182
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69532,  Smallest:  0.00085,  Largest:  0.79017,  Average:  0.02572
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03053,  Smallest:  0.00056,  Largest:  0.99953,  Average:  0.50130
# Category, # Predictions, # Correct:  0.0, 35539, 35503
# Category, # Predictions, # Correct:  0.5, 35539, 33057
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69565,  Smallest:  0.00086,  Largest:  0.79201,  Average:  0.02507
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03297,  Smallest:  0.00056,  Largest:  0.99954,  Average:  0.50340
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33048
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69559,  Smallest:  0.00085,  Largest:  0.79077,  Average:  0.02520
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03246,  Smallest:  0.00054,  Largest:  0.99955,  Average:  0.50116
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33086
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69536,  Smallest:  0.00086,  Largest:  0.79702,  Average:  0.02564
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03320,  Smallest:  0.00056,  Largest:  0.99955,  Average:  0.50291
# Category, # Predictions, # Correct:  0.0, 35539, 35501
# Category, # Predictions, # Correct:  0.5, 35539, 32947
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69548,  Smallest:  0.00085,  Largest:  0.79095,  Average:  0.02542
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03262,  Smallest:  0.00056,  Largest:  0.99954,  Average:  0.50222
# Category, # Predictions, # Correct:  0.0, 35539, 35503
# Category, # Predictions, # Correct:  0.5, 35539, 33164
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69530,  Smallest:  0.00086,  Largest:  0.79022,  Average:  0.02578
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03097,  Smallest:  0.00055,  Largest:  0.99953,  Average:  0.50111
# Category, # Predictions, # Correct:  0.0, 35539, 35501
# Category, # Predictions, # Correct:  0.5, 35539, 32945
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69530,  Smallest:  0.00085,  Largest:  0.79678,  Average:  0.02577
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03283,  Smallest:  0.00054,  Largest:  0.99955,  Average:  0.50338
# Category, # Predictions, # Correct:  0.0, 35539, 35501
# Category, # Predictions, # Correct:  0.5, 35539, 33155
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69540,  Smallest:  0.00088,  Largest:  0.79188,  Average:  0.02558
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03158,  Smallest:  0.00054,  Largest:  0.99955,  Average:  0.50436
# Category, # Predictions, # Correct:  0.0, 35539, 35501
# Category, # Predictions, # Correct:  0.5, 35539, 33241
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69532,  Smallest:  0.00088,  Largest:  0.79411,  Average:  0.02573
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03297,  Smallest:  0.00055,  Largest:  0.99955,  Average:  0.50142
# Category, # Predictions, # Correct:  0.0, 35539, 35503
# Category, # Predictions, # Correct:  0.5, 35539, 32864
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69570,  Smallest:  0.00085,  Largest:  0.79002,  Average:  0.02497
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03264,  Smallest:  0.00055,  Largest:  0.99955,  Average:  0.50010
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33029
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69560,  Smallest:  0.00084,  Largest:  0.78935,  Average:  0.02519
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03139,  Smallest:  0.00054,  Largest:  0.99954,  Average:  0.50018
# Category, # Predictions, # Correct:  0.0, 35539, 35497
# Category, # Predictions, # Correct:  0.5, 35539, 33361
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69536,  Smallest:  0.00085,  Largest:  0.79618,  Average:  0.02564
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03227,  Smallest:  0.00053,  Largest:  0.99954,  Average:  0.50228
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 32911
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69546,  Smallest:  0.00087,  Largest:  0.79758,  Average:  0.02545
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03100,  Smallest:  0.00054,  Largest:  0.99954,  Average:  0.50395
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33273
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69545,  Smallest:  0.00085,  Largest:  0.79462,  Average:  0.02548
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03217,  Smallest:  0.00055,  Largest:  0.99955,  Average:  0.50154
# Category, # Predictions, # Correct:  0.0, 35539, 35503
# Category, # Predictions, # Correct:  0.5, 35539, 33082
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69568,  Smallest:  0.00084,  Largest:  0.79262,  Average:  0.02503
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03194,  Smallest:  0.00053,  Largest:  0.99955,  Average:  0.50046
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33179
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69558,  Smallest:  0.00085,  Largest:  0.79780,  Average:  0.02522
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03189,  Smallest:  0.00054,  Largest:  0.99955,  Average:  0.50370
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 32958
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69549,  Smallest:  0.00086,  Largest:  0.79534,  Average:  0.02539
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03100,  Smallest:  0.00053,  Largest:  0.99956,  Average:  0.50116
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33449
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69541,  Smallest:  0.00085,  Largest:  0.79758,  Average:  0.02554
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03204,  Smallest:  0.00053,  Largest:  0.99956,  Average:  0.50268
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33311
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69548,  Smallest:  0.00084,  Largest:  0.79134,  Average:  0.02541
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03079,  Smallest:  0.00052,  Largest:  0.99956,  Average:  0.50363
# Category, # Predictions, # Correct:  0.0, 35539, 35501
# Category, # Predictions, # Correct:  0.5, 35539, 33247
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69554,  Smallest:  0.00085,  Largest:  0.79385,  Average:  0.02529
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03333,  Smallest:  0.00052,  Largest:  0.99957,  Average:  0.50249
# Category, # Predictions, # Correct:  0.0, 35539, 35501
# Category, # Predictions, # Correct:  0.5, 35539, 33082
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69553,  Smallest:  0.00086,  Largest:  0.79017,  Average:  0.02531
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03156,  Smallest:  0.00053,  Largest:  0.99956,  Average:  0.50038
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33225
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69565,  Smallest:  0.00084,  Largest:  0.79257,  Average:  0.02508
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03021,  Smallest:  0.00053,  Largest:  0.99957,  Average:  0.50406
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33480
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69557,  Smallest:  0.00085,  Largest:  0.79006,  Average:  0.02523
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03060,  Smallest:  0.00052,  Largest:  0.99958,  Average:  0.50119
# Category, # Predictions, # Correct:  0.0, 35539, 35499
# Category, # Predictions, # Correct:  0.5, 35539, 33402
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69574,  Smallest:  0.00084,  Largest:  0.79009,  Average:  0.02490
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# Train:
#  Average loss:  0.03030,  Smallest:  0.00051,  Largest:  0.99958,  Average:  0.50162
# Category, # Predictions, # Correct:  0.0, 35539, 35501
# Category, # Predictions, # Correct:  0.5, 35539, 33531
# Category, # Predictions, # Correct:  1.0, 35539, 35539
# Test:
#  Average loss:  0.69572,  Smallest:  0.00083,  Largest:  0.78535,  Average:  0.02494
# Category, # Predictions, # Correct:  0.0, 3300, 3300
# Category, # Predictions, # Correct:  0.5, 1278, 0
# Category, # Predictions, # Correct:  1.0, 8934, 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-7-0ad3f078b01e> in update_stats(stats, outputs, values, loss)
#      30 def update_stats(stats: Stats, outputs, values, loss):
#      31     stats.n += len(values)
# ---> 32     stats.average_value += outputs.sum().item()
#      33     stats.loss += loss.item() * len(values)
#      34     stats.smallest = min(stats.smallest, torch.min(outputs).item())
#
# KeyboardInterrupt:

# %%
# validate
with torch.set_grad_enabled(False):
    net = net.eval()
    correct = {i : 0 for i in [0, 0.5, 1]}
    total = {i : 0 for i in [0, 0.5, 1]}
    for board, value in test_gen:
        board, value = board.to(device), value.to(device)

        outputs = net(board)
        categories = categorise_predictions(outputs)

        for k in correct:
            idx = (categories == k).nonzero()
            total[k] += len(idx)
            correct[k] += (categories[idx] == value[idx]).nonzero().sum().item()
    for k in correct:
        print('Category, # Predictions, Accuracy of the network on the test%s: %d %d %%' % (
            k,
            total[k],
            (100 * float(correct[k]) / float(total[k])) if total[k] != 0 else 0.))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-af11dd7c5d98> in <module>
#      13             idx = (categories == k).nonzero()
#      14             total[k] += len(idx)
# ---> 15             correct[k] += (categories[idx] == value[idx]).nonzero().sum().item()
#      16     for k in correct:
#      17         print('Category, # Predictions, Accuracy of the network on the test%s: %d %d %%' % (
#
# RuntimeError: The size of tensor a (2) must match the size of tensor b (0) at non-singleton dimension 1

# %%
assert(False)
# save that crap
torch.save({
    'net_state_dict': net.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'loss': loss
},
    open('/home/richard/Downloads/nn.pth', 'wb'))

# %%
# alternatively load it
assert(False)
checkpoint = torch.load('/home/richard/Downloads/nn.pth')
net.load_state_dict(checkpoint['net_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
loss = checkpoint['loss']

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
