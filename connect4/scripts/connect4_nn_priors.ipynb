# %%
# %matplotlib inline

import numpy as np
import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data

from copy import copy
from sklearn.model_selection import train_test_split

# https://discuss.pytorch.org/t/output-of-resnet34-network-depends-on-the-batch-size/21647
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.manual_seed(999)
np.random.seed(0)

# %%
n_epocs = 10000
epochs_per_stats = 1
batch_size = 4096
test_size = 0.2
# learning_rate = 0.002 * (batch_size / 1024.0)
learning_rate = 0.01
momentum = 0.9

WORKING_DIR = '/home/richard/Downloads/nn/PSU_back/'

# %%
with open('/home/richard/data/connect4/7ply_boards.pkl', 'rb') as f:
    boards = pickle.load(f)
with open ('/home/richard/data/connect4/7ply_values.pkl', 'rb') as f:
    values = pickle.load(f)
with open('/home/richard/data/connect4/7ply_priors.pkl', 'rb') as f:
    priors = pickle.load(f)

priors = list(map(lambda x: x / np.sum(x) if np.sum(x) > 0.0 else np.zeros((7,)), priors))

# %%
from connect4.neural.nn_pytorch import Connect4Dataset

train = Connect4Dataset(boards, values, priors, to_move_channel=False)

train_gen = data.DataLoader(train, batch_size, shuffle=True)
# Out:
# Creating dataset with 27989 positions

# %%
from connect4.neural.nn_pytorch import build_policy_net

net = build_policy_net()

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01)
#   )
#   (1): Sequential(
#     (0): ResidualLayer(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.01)
#     )
#     (1): ResidualLayer(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.01)
#     )
#     (2): ResidualLayer(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (batch_norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (2): PolicyHead(
#     (conv1): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1))
#     (batch_norm): BatchNorm2d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): LeakyReLU(negative_slope=0.01)
#     (fc1): Linear(in_features=84, out_features=7, bias=True)
#   )
#   (3): Softmax()
# )

# %%
# criterion = nn.CrossEntropyLoss()
criterion = nn.BCELoss()

optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum)
# optimizer = optim.Adam(net.parameters())

# %%
# %%time

for epoch in range(n_epocs):
    net = net.train()
    
    for board, _, prior in train_gen:
        board, prior = board.to(device), prior.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        output = net(board)

        loss = criterion(output, prior)
        loss.backward()
        optimizer.step()
        
    # print last output
    print("epoch {}, loss: {}".format(epoch, loss))
    print(output[0], prior[0])
            
print('Finished Training')
# Out:
# /home/richard/miniconda3/lib/python3.7/site-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch 0, loss: 0.4080538749694824
# tensor([0.1737, 0.1630, 0.1086, 0.1353, 0.1210, 0.1561, 0.1424],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([1., 0., 0., 0., 0., 0., 0.], device='cuda:0')
# epoch 1, loss: 0.4071711301803589
# tensor([0.1659, 0.1352, 0.1442, 0.1401, 0.1240, 0.1465, 0.1442],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.2500, 0.0000, 0.0000, 0.2500, 0.0000, 0.2500],
#        device='cuda:0')
# epoch 2, loss: 0.40730640292167664
# tensor([0.1581, 0.1441, 0.1493, 0.1252, 0.1428, 0.1450, 0.1355],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5000],
#        device='cuda:0')
# epoch 3, loss: 0.4067128300666809
# tensor([0.1730, 0.1375, 0.1076, 0.1270, 0.1215, 0.1525, 0.1809],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.2500, 0.0000, 0.0000, 0.2500, 0.0000, 0.2500],
#        device='cuda:0')
# epoch 4, loss: 0.40575361251831055
# tensor([0.1795, 0.1296, 0.1213, 0.1263, 0.1374, 0.1511, 0.1548],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.0000, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000],
#        device='cuda:0')
# epoch 5, loss: 0.40587595105171204
# tensor([0.1618, 0.1407, 0.1473, 0.1219, 0.1398, 0.1471, 0.1414],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 6, loss: 0.4049927294254303
# tensor([0.1803, 0.1351, 0.1199, 0.1191, 0.1260, 0.1372, 0.1825],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 7, loss: 0.40458759665489197
# tensor([0.1773, 0.1377, 0.1355, 0.1135, 0.1249, 0.1483, 0.1628],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 1., 0.], device='cuda:0')
# epoch 8, loss: 0.4047655165195465
# tensor([0.1887, 0.1325, 0.1110, 0.1276, 0.1154, 0.1451, 0.1797],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2000, 0.2000, 0.0000, 0.0000, 0.2000, 0.2000, 0.2000],
#        device='cuda:0')
# epoch 9, loss: 0.40404000878334045
# tensor([0.1687, 0.1111, 0.1138, 0.1620, 0.1040, 0.1434, 0.1969],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 1., 0., 0., 0.], device='cuda:0')
# epoch 10, loss: 0.4035075306892395
# tensor([0.1833, 0.1265, 0.1307, 0.1296, 0.1305, 0.1339, 0.1653],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 11, loss: 0.40433987975120544
# tensor([0.1674, 0.1247, 0.1421, 0.1320, 0.1357, 0.1415, 0.1567],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.0000, 0.3333, 0.0000, 0.0000, 0.0000, 0.3333],
#        device='cuda:0')
# epoch 12, loss: 0.40381038188934326
# tensor([0.1867, 0.1503, 0.1289, 0.0941, 0.1445, 0.1244, 0.1711],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 13, loss: 0.4037072956562042
# tensor([0.1807, 0.1380, 0.1204, 0.1031, 0.1453, 0.1392, 0.1734],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 14, loss: 0.40360960364341736
# tensor([0.2054, 0.1271, 0.1205, 0.1022, 0.1297, 0.1333, 0.1818],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 15, loss: 0.40303462743759155
# tensor([0.1716, 0.1124, 0.1158, 0.1554, 0.1070, 0.1453, 0.1926],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 1., 0., 0., 0.], device='cuda:0')
# epoch 16, loss: 0.40311747789382935
# tensor([0.1617, 0.1214, 0.1208, 0.0767, 0.1813, 0.1291, 0.2090],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.3333, 0.3333],
#        device='cuda:0')
# epoch 17, loss: 0.4024328291416168
# tensor([0.1739, 0.1377, 0.1328, 0.1028, 0.1277, 0.1346, 0.1903],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 1., 0., 0., 0., 0., 0.], device='cuda:0')
# epoch 18, loss: 0.40204253792762756
# tensor([0.1661, 0.1542, 0.1348, 0.0919, 0.1349, 0.1498, 0.1684],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 1., 0., 0., 0., 0., 0.], device='cuda:0')
# epoch 19, loss: 0.4030548930168152
# tensor([0.1694, 0.1573, 0.1106, 0.1136, 0.1179, 0.1326, 0.1986],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 20, loss: 0.40182462334632874
# tensor([0.1890, 0.1218, 0.1224, 0.0976, 0.1275, 0.1314, 0.2103],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 21, loss: 0.4011807441711426
# tensor([0.1849, 0.1368, 0.1169, 0.1089, 0.1294, 0.1405, 0.1827],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.2500],
#        device='cuda:0')
# epoch 22, loss: 0.4018360376358032
# tensor([0.1884, 0.1149, 0.1272, 0.1185, 0.1123, 0.1346, 0.2041],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2000, 0.2000, 0.0000, 0.2000, 0.0000, 0.2000, 0.2000],
#        device='cuda:0')
# epoch 23, loss: 0.40122008323669434
# tensor([0.2024, 0.1463, 0.1291, 0.0864, 0.1218, 0.1041, 0.2097],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 1., 0., 0., 0., 0.], device='cuda:0')
# epoch 24, loss: 0.4012840986251831
# tensor([0.2039, 0.1216, 0.1256, 0.1047, 0.1310, 0.1255, 0.1877],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 25, loss: 0.40234342217445374
# tensor([0.1915, 0.1557, 0.1013, 0.0962, 0.1224, 0.1146, 0.2184],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2000, 0.0000, 0.2000, 0.2000, 0.2000, 0.0000, 0.2000],
#        device='cuda:0')
# epoch 26, loss: 0.40148136019706726
# tensor([0.1853, 0.1293, 0.1100, 0.0933, 0.1256, 0.1529, 0.2037],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#        device='cuda:0')
# epoch 27, loss: 0.401361346244812
# tensor([0.1830, 0.1220, 0.1205, 0.0881, 0.1308, 0.1373, 0.2184],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 28, loss: 0.4011646509170532
# tensor([0.2029, 0.1042, 0.0818, 0.0922, 0.0841, 0.1742, 0.2606],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 29, loss: 0.40108609199523926
# tensor([0.2010, 0.1198, 0.1205, 0.1165, 0.1236, 0.1410, 0.1775],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 30, loss: 0.40029478073120117
# tensor([0.2097, 0.1211, 0.1219, 0.1009, 0.0998, 0.1512, 0.1954],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 31, loss: 0.39991262555122375
# tensor([0.2174, 0.1220, 0.1183, 0.1020, 0.1061, 0.1352, 0.1990],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 32, loss: 0.40037214756011963
# tensor([0.2527, 0.1107, 0.0913, 0.0895, 0.1003, 0.1251, 0.2305],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 33, loss: 0.3999937176704407
# tensor([0.1877, 0.1241, 0.1331, 0.0944, 0.1322, 0.1424, 0.1861],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 34, loss: 0.4006364643573761
# tensor([0.1809, 0.1434, 0.1283, 0.1070, 0.1308, 0.1287, 0.1809],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 35, loss: 0.3997247517108917
# tensor([0.2746, 0.1190, 0.0805, 0.0915, 0.1020, 0.1272, 0.2052],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 36, loss: 0.3994678258895874
# tensor([0.2098, 0.1147, 0.1139, 0.0806, 0.1227, 0.1638, 0.1944],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 1., 0.], device='cuda:0')
# epoch 37, loss: 0.39910924434661865
# tensor([0.1952, 0.1133, 0.1292, 0.1097, 0.1198, 0.1385, 0.1943],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 0., 1.], device='cuda:0')
# epoch 38, loss: 0.39938247203826904
# tensor([0.2511, 0.1259, 0.1013, 0.0938, 0.1019, 0.1435, 0.1825],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.3333, 0.0000],
#        device='cuda:0')
# epoch 39, loss: 0.40032079815864563
# tensor([0.2063, 0.1383, 0.1056, 0.1109, 0.1261, 0.1381, 0.1747],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.0000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5000],
#        device='cuda:0')
# epoch 40, loss: 0.39898040890693665
# tensor([0.2031, 0.1344, 0.1184, 0.1309, 0.1011, 0.1215, 0.1907],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.0000, 0.3333, 0.0000, 0.0000, 0.0000, 0.3333],
#        device='cuda:0')
# epoch 41, loss: 0.39860689640045166
# tensor([0.1788, 0.1111, 0.1247, 0.0708, 0.1614, 0.1647, 0.1887],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.1667, 0.0000, 0.1667, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 42, loss: 0.39851507544517517
# tensor([0.2045, 0.1223, 0.1155, 0.1031, 0.0888, 0.1354, 0.2305],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 0., 1.], device='cuda:0')
# epoch 43, loss: 0.3994758129119873
# tensor([0.1893, 0.1120, 0.1277, 0.1037, 0.1219, 0.1571, 0.1884],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 44, loss: 0.39855071902275085
# tensor([0.2022, 0.1273, 0.1286, 0.1072, 0.1251, 0.1213, 0.1882],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.0000, 0.0000, 0.0000, 0.3333, 0.0000, 0.3333],
#        device='cuda:0')
# epoch 45, loss: 0.39778855443000793
# tensor([0.1923, 0.1509, 0.1286, 0.0925, 0.1136, 0.0954, 0.2267],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 1., 0., 0., 0., 0.], device='cuda:0')
# epoch 46, loss: 0.39761316776275635
# tensor([0.2178, 0.1405, 0.1051, 0.0992, 0.1084, 0.1508, 0.1781],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 47, loss: 0.3974457383155823
# tensor([0.1583, 0.1484, 0.1016, 0.0777, 0.1372, 0.1424, 0.2344],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 48, loss: 0.39685380458831787
# tensor([0.1799, 0.1249, 0.1400, 0.1153, 0.1303, 0.1530, 0.1565],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 49, loss: 0.3972223401069641
# tensor([0.2400, 0.1384, 0.0939, 0.0722, 0.1211, 0.1064, 0.2279],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 50, loss: 0.3972230553627014
# tensor([0.2634, 0.1246, 0.0987, 0.0912, 0.0961, 0.1201, 0.2059],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([1., 0., 0., 0., 0., 0., 0.], device='cuda:0')
# epoch 51, loss: 0.3962407112121582
# tensor([0.1635, 0.1289, 0.1567, 0.1216, 0.1377, 0.1036, 0.1880],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 52, loss: 0.3972383737564087
# tensor([0.1701, 0.1350, 0.1120, 0.0828, 0.1235, 0.1457, 0.2309],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 0., 1.], device='cuda:0')
# epoch 53, loss: 0.39736589789390564
# tensor([0.1991, 0.1437, 0.1224, 0.1035, 0.1240, 0.1394, 0.1679],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 1., 0., 0., 0., 0., 0.], device='cuda:0')
# epoch 54, loss: 0.39609891176223755
# tensor([0.1890, 0.1319, 0.1434, 0.1218, 0.1245, 0.1490, 0.1406],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 55, loss: 0.3959863483905792
# tensor([0.2547, 0.1709, 0.0928, 0.0800, 0.0921, 0.1141, 0.1953],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#        device='cuda:0')
# epoch 56, loss: 0.39559781551361084
# tensor([0.2393, 0.1510, 0.0793, 0.1310, 0.0897, 0.1295, 0.1802],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.2500, 0.2500],
#        device='cuda:0')
# epoch 57, loss: 0.3957535922527313
# tensor([0.1812, 0.1411, 0.1322, 0.1105, 0.1268, 0.1341, 0.1741],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 58, loss: 0.3951769173145294
# tensor([0.2815, 0.1394, 0.0970, 0.0631, 0.1170, 0.0974, 0.2046],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.3333],
#        device='cuda:0')
# epoch 59, loss: 0.3948005437850952
# tensor([0.1865, 0.1235, 0.1428, 0.1011, 0.1103, 0.1587, 0.1770],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 60, loss: 0.3961036503314972
# tensor([0.1756, 0.1131, 0.1278, 0.1059, 0.1316, 0.1329, 0.2131],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5000],
#        device='cuda:0')
# epoch 61, loss: 0.39486557245254517
# tensor([0.1876, 0.1087, 0.1053, 0.0959, 0.1089, 0.1491, 0.2446],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 62, loss: 0.39502257108688354
# tensor([0.1860, 0.1256, 0.1138, 0.1090, 0.1397, 0.1329, 0.1929],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 63, loss: 0.39337998628616333
# tensor([0.2258, 0.1204, 0.1242, 0.1007, 0.1253, 0.1452, 0.1584],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 64, loss: 0.3946515917778015
# tensor([0.2383, 0.1606, 0.0959, 0.1117, 0.1110, 0.1002, 0.1823],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 65, loss: 0.392339825630188
# tensor([0.2002, 0.1298, 0.1100, 0.1398, 0.1219, 0.1049, 0.1933],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 66, loss: 0.39363810420036316
# tensor([0.1970, 0.1462, 0.1072, 0.1178, 0.1162, 0.1481, 0.1675],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 1., 0., 0., 0.], device='cuda:0')
# epoch 67, loss: 0.3932071924209595
# tensor([0.2048, 0.1001, 0.1282, 0.0769, 0.1212, 0.1399, 0.2289],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.0000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000],
#        device='cuda:0')
# epoch 68, loss: 0.39244988560676575
# tensor([0.1601, 0.1886, 0.1452, 0.0555, 0.1700, 0.1090, 0.1716],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 69, loss: 0.3931407332420349
# tensor([0.2221, 0.1183, 0.0911, 0.0727, 0.1693, 0.1303, 0.1963],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 70, loss: 0.39261990785598755
# tensor([0.2652, 0.1278, 0.1173, 0.0712, 0.0911, 0.0966, 0.2307],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.1667, 0.0000, 0.1667, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 71, loss: 0.3913588523864746
# tensor([0.1901, 0.1475, 0.1350, 0.1154, 0.1102, 0.1721, 0.1298],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([1., 0., 0., 0., 0., 0., 0.], device='cuda:0')
# epoch 72, loss: 0.39137837290763855
# tensor([0.2023, 0.1272, 0.0907, 0.0684, 0.1076, 0.2492, 0.1547],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.3333, 0.3333],
#        device='cuda:0')
# epoch 73, loss: 0.39160653948783875
# tensor([0.3189, 0.1360, 0.0842, 0.0687, 0.0974, 0.1037, 0.1912],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.3333],
#        device='cuda:0')
# epoch 74, loss: 0.3921215534210205
# tensor([0.2125, 0.1471, 0.1093, 0.0926, 0.0869, 0.1695, 0.1820],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 75, loss: 0.38936153054237366
# tensor([0.1926, 0.1052, 0.0897, 0.1123, 0.1456, 0.1393, 0.2153],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5000],
#        device='cuda:0')
# epoch 76, loss: 0.39060455560684204
# tensor([0.1773, 0.1372, 0.1265, 0.1120, 0.1252, 0.1458, 0.1759],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 77, loss: 0.3908105790615082
# tensor([0.1824, 0.1509, 0.1203, 0.1149, 0.1150, 0.1475, 0.1690],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 78, loss: 0.3906855285167694
# tensor([0.2252, 0.1506, 0.1427, 0.0821, 0.0991, 0.1303, 0.1700],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5000],
#        device='cuda:0')
# epoch 79, loss: 0.3912348747253418
# tensor([0.1836, 0.1771, 0.1189, 0.0892, 0.0880, 0.1557, 0.1876],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.2000, 0.2000],
#        device='cuda:0')
# epoch 80, loss: 0.3895910084247589
# tensor([0.2603, 0.1825, 0.0797, 0.0769, 0.1160, 0.0949, 0.1897],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#        device='cuda:0')
# epoch 81, loss: 0.38970881700515747
# tensor([0.2019, 0.1045, 0.1149, 0.0623, 0.1195, 0.1750, 0.2218],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 0., 1.], device='cuda:0')
# epoch 82, loss: 0.39019131660461426
# tensor([0.2214, 0.1693, 0.0815, 0.0869, 0.0717, 0.1628, 0.2064],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 83, loss: 0.3887881338596344
# tensor([0.1978, 0.1880, 0.0727, 0.0514, 0.1198, 0.1202, 0.2501],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.2500, 0.2500],
#        device='cuda:0')
# epoch 84, loss: 0.3889492452144623
# tensor([0.2120, 0.1727, 0.0725, 0.0566, 0.0893, 0.0918, 0.3051],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 85, loss: 0.3891957402229309
# tensor([0.1956, 0.1473, 0.1317, 0.1012, 0.1067, 0.1047, 0.2129],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 86, loss: 0.3893088698387146
# tensor([0.1583, 0.1070, 0.1340, 0.0947, 0.1025, 0.1748, 0.2288],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.3333, 0.3333],
#        device='cuda:0')
# epoch 87, loss: 0.389699250459671
# tensor([0.2428, 0.0788, 0.1106, 0.0591, 0.1270, 0.1754, 0.2063],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.2500, 0.2500],
#        device='cuda:0')
# epoch 88, loss: 0.38877642154693604
# tensor([0.2202, 0.0981, 0.1308, 0.0606, 0.1409, 0.1345, 0.2149],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 89, loss: 0.3881208598613739
# tensor([0.2089, 0.1120, 0.1146, 0.0999, 0.1075, 0.1102, 0.2470],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.0000, 0.2500, 0.0000, 0.0000, 0.2500, 0.2500],
#        device='cuda:0')
# epoch 90, loss: 0.3875134587287903
# tensor([0.2490, 0.1405, 0.1187, 0.1091, 0.0759, 0.1181, 0.1887],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5000],
#        device='cuda:0')
# epoch 91, loss: 0.38755908608436584
# tensor([0.1474, 0.2446, 0.1352, 0.0361, 0.0901, 0.1414, 0.2052],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 92, loss: 0.3884122669696808
# tensor([0.1836, 0.1523, 0.1389, 0.1379, 0.1142, 0.1150, 0.1580],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 93, loss: 0.38707470893859863
# tensor([0.2770, 0.2131, 0.0593, 0.0825, 0.0773, 0.0687, 0.2222],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 1., 0., 0., 0., 0., 0.], device='cuda:0')
# epoch 94, loss: 0.38669511675834656
# tensor([0.2211, 0.1186, 0.1064, 0.0515, 0.0893, 0.1630, 0.2501],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.1667, 0.0000, 0.1667, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 95, loss: 0.3890872895717621
# tensor([0.3155, 0.1719, 0.1437, 0.0740, 0.0695, 0.0685, 0.1569],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.2500],
#        device='cuda:0')
# epoch 96, loss: 0.3853902816772461
# tensor([0.1665, 0.0937, 0.1108, 0.2040, 0.1118, 0.1471, 0.1663],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 97, loss: 0.3849804997444153
# tensor([0.2151, 0.1311, 0.0784, 0.1046, 0.0946, 0.1486, 0.2275],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.2500, 0.2500, 0.0000, 0.2500, 0.0000, 0.0000],
#        device='cuda:0')
# epoch 98, loss: 0.38677769899368286
# tensor([0.2043, 0.1457, 0.1544, 0.0442, 0.1834, 0.0616, 0.2064],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.0000, 0.2500, 0.2500, 0.0000, 0.2500, 0.0000, 0.2500],
#        device='cuda:0')
# epoch 99, loss: 0.3877519369125366
# tensor([0.2115, 0.2677, 0.0552, 0.0573, 0.0602, 0.1900, 0.1582],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.3333, 0.0000],
#        device='cuda:0')
# epoch 100, loss: 0.38893818855285645
# tensor([0.2845, 0.1055, 0.0688, 0.0517, 0.0888, 0.1554, 0.2454],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 101, loss: 0.3880719542503357
# tensor([0.3920, 0.1139, 0.0829, 0.0427, 0.0630, 0.1056, 0.1999],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.0000, 0.3333, 0.0000, 0.0000, 0.0000, 0.3333, 0.3333],
#        device='cuda:0')
# epoch 102, loss: 0.3864974081516266
# tensor([0.2851, 0.1008, 0.0824, 0.1054, 0.0917, 0.1073, 0.2274],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.2000, 0.2000],
#        device='cuda:0')
# epoch 103, loss: 0.38583043217658997
# tensor([0.1234, 0.1823, 0.1337, 0.0687, 0.1928, 0.1281, 0.1711],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 104, loss: 0.38609254360198975
# tensor([0.2321, 0.1489, 0.0858, 0.0925, 0.0648, 0.1799, 0.1960],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 105, loss: 0.38608676195144653
# tensor([0.2213, 0.1501, 0.1184, 0.1289, 0.1261, 0.1237, 0.1316],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 106, loss: 0.3847529888153076
# tensor([0.1967, 0.1078, 0.0891, 0.0792, 0.0859, 0.1223, 0.3190],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 0., 1.], device='cuda:0')
# epoch 107, loss: 0.38491612672805786
# tensor([0.1532, 0.1497, 0.0959, 0.1496, 0.1483, 0.1525, 0.1508],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 108, loss: 0.38410696387290955
# tensor([0.1854, 0.0988, 0.2254, 0.0535, 0.0907, 0.1707, 0.1754],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.0000, 0.0000, 0.3333, 0.0000, 0.3333, 0.0000, 0.3333],
#        device='cuda:0')
# epoch 109, loss: 0.3848850727081299
# tensor([0.2068, 0.0976, 0.1459, 0.0855, 0.1369, 0.1180, 0.2092],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 110, loss: 0.3833158314228058
# tensor([0.1439, 0.1056, 0.2788, 0.0682, 0.1281, 0.0965, 0.1790],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 1., 0., 0., 0., 0.], device='cuda:0')
# epoch 111, loss: 0.3852848410606384
# tensor([0.1968, 0.1689, 0.0716, 0.0973, 0.0493, 0.1167, 0.2995],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([1., 0., 0., 0., 0., 0., 0.], device='cuda:0')
# epoch 112, loss: 0.3837401270866394
# tensor([0.0100, 0.0071, 0.0211, 0.9247, 0.0132, 0.0103, 0.0137],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 1., 0., 0., 0.], device='cuda:0')
# epoch 113, loss: 0.3845561444759369
# tensor([0.0116, 0.0115, 0.0299, 0.9101, 0.0096, 0.0128, 0.0146],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 1., 0., 0., 0.], device='cuda:0')
# epoch 114, loss: 0.3849858343601227
# tensor([0.1965, 0.1612, 0.1266, 0.1481, 0.0975, 0.0923, 0.1778],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 0., 1.], device='cuda:0')
# epoch 115, loss: 0.3820776343345642
# tensor([0.1110, 0.2956, 0.2021, 0.0435, 0.1233, 0.0914, 0.1331],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 116, loss: 0.3833644986152649
# tensor([0.2073, 0.1383, 0.1217, 0.0528, 0.1962, 0.0752, 0.2084],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5000],
#        device='cuda:0')
# epoch 117, loss: 0.3854025602340698
# tensor([0.2993, 0.1203, 0.0922, 0.0650, 0.1375, 0.1119, 0.1738],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 118, loss: 0.38304877281188965
# tensor([0.1537, 0.1792, 0.1255, 0.1191, 0.1243, 0.1686, 0.1296],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 119, loss: 0.3846428394317627
# tensor([0.2372, 0.1979, 0.1124, 0.0731, 0.1078, 0.1061, 0.1655],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 120, loss: 0.38243815302848816
# tensor([0.1635, 0.1125, 0.1336, 0.1268, 0.1663, 0.1275, 0.1698],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 121, loss: 0.38236913084983826
# tensor([0.2787, 0.0856, 0.0845, 0.0642, 0.1077, 0.1620, 0.2172],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 122, loss: 0.3832479417324066
# tensor([0.2013, 0.0996, 0.1254, 0.1255, 0.1667, 0.1154, 0.1661],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 123, loss: 0.38060522079467773
# tensor([0.1130, 0.0696, 0.1485, 0.0684, 0.0942, 0.4123, 0.0940],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 1., 0.], device='cuda:0')
# epoch 124, loss: 0.3815752863883972
# tensor([0.1765, 0.1338, 0.1517, 0.0952, 0.0983, 0.0995, 0.2450],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 125, loss: 0.38227060437202454
# tensor([0.1194, 0.1271, 0.1860, 0.1341, 0.1761, 0.1229, 0.1344],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 126, loss: 0.3800375163555145
# tensor([0.2058, 0.1889, 0.1536, 0.0619, 0.1209, 0.0841, 0.1848],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.0000, 0.2500, 0.0000, 0.0000, 0.2500, 0.2500, 0.2500],
#        device='cuda:0')
# epoch 127, loss: 0.38193032145500183
# tensor([0.1360, 0.1269, 0.1232, 0.1491, 0.1343, 0.1569, 0.1734],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 128, loss: 0.3827093243598938
# tensor([0.1733, 0.1173, 0.1309, 0.0830, 0.1925, 0.1367, 0.1663],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 1., 0., 0.], device='cuda:0')
# epoch 129, loss: 0.37968575954437256
# tensor([0.1962, 0.1896, 0.0659, 0.0982, 0.2495, 0.0677, 0.1328],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.0000, 0.1667, 0.1667, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 130, loss: 0.3819355368614197
# tensor([0.2221, 0.1042, 0.1899, 0.0642, 0.1221, 0.1028, 0.1947],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.1667, 0.0000, 0.1667, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 131, loss: 0.38262441754341125
# tensor([0.0449, 0.1316, 0.0747, 0.0467, 0.6051, 0.0286, 0.0684],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 1., 0., 0.], device='cuda:0')
# epoch 132, loss: 0.3807295262813568
# tensor([0.1520, 0.1426, 0.1232, 0.1540, 0.1305, 0.1371, 0.1606],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 133, loss: 0.38149943947792053
# tensor([0.0429, 0.0396, 0.0664, 0.0712, 0.6846, 0.0271, 0.0684],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 134, loss: 0.3807505667209625
# tensor([0.1743, 0.1403, 0.1158, 0.1547, 0.1210, 0.1221, 0.1718],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 135, loss: 0.38106489181518555
# tensor([0.2996, 0.1261, 0.0613, 0.0328, 0.1571, 0.0724, 0.2507],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 0., 1.], device='cuda:0')
# epoch 136, loss: 0.38066408038139343
# tensor([0.1414, 0.1800, 0.1188, 0.1249, 0.1048, 0.1540, 0.1761],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 137, loss: 0.3790837228298187
# tensor([0.0346, 0.0402, 0.0329, 0.0643, 0.7040, 0.0607, 0.0633],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 1., 0., 0.], device='cuda:0')
# epoch 138, loss: 0.3802258372306824
# tensor([0.1050, 0.3878, 0.0786, 0.0186, 0.1009, 0.1369, 0.1722],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 139, loss: 0.38148751854896545
# tensor([0.2799, 0.0366, 0.0920, 0.0358, 0.1014, 0.0643, 0.3900],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.3333, 0.0000, 0.0000, 0.0000, 0.3333, 0.0000, 0.3333],
#        device='cuda:0')
# epoch 140, loss: 0.3798423409461975
# tensor([0.3222, 0.0917, 0.0410, 0.0507, 0.0533, 0.1655, 0.2756],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.5000],
#        device='cuda:0')
# epoch 141, loss: 0.3803381621837616
# tensor([0.0561, 0.0811, 0.0601, 0.0750, 0.4640, 0.1289, 0.1349],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 142, loss: 0.37977135181427
# tensor([0.1838, 0.3007, 0.0872, 0.0802, 0.0674, 0.0834, 0.1972],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 143, loss: 0.37913817167282104
# tensor([0.3008, 0.3052, 0.0831, 0.0307, 0.0497, 0.0797, 0.1508],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([1., 0., 0., 0., 0., 0., 0.], device='cuda:0')
# epoch 144, loss: 0.38019686937332153
# tensor([0.1528, 0.1268, 0.1622, 0.1372, 0.1546, 0.1185, 0.1480],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 145, loss: 0.380321204662323
# tensor([0.1324, 0.1721, 0.1648, 0.1367, 0.1342, 0.1284, 0.1315],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 146, loss: 0.3783697485923767
# tensor([0.1563, 0.1439, 0.1276, 0.0767, 0.1537, 0.1209, 0.2210],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.0000, 0.2500, 0.2500, 0.0000, 0.2500, 0.2500, 0.0000],
#        device='cuda:0')
# epoch 147, loss: 0.37918534874916077
# tensor([0.2935, 0.1108, 0.0906, 0.0368, 0.0883, 0.1018, 0.2783],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.2500, 0.2500],
#        device='cuda:0')
# epoch 148, loss: 0.37946125864982605
# tensor([0.1845, 0.1838, 0.2086, 0.0660, 0.1333, 0.0814, 0.1424],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 1., 0., 0., 0., 0.], device='cuda:0')
# epoch 149, loss: 0.3799407482147217
# tensor([0.1256, 0.1352, 0.2053, 0.1183, 0.1465, 0.1675, 0.1016],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 150, loss: 0.3780328035354614
# tensor([0.2488, 0.1315, 0.0539, 0.0534, 0.1363, 0.1406, 0.2355],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.0000, 0.1667, 0.1667, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 151, loss: 0.3755802810192108
# tensor([0.2233, 0.1779, 0.0665, 0.0457, 0.1480, 0.1499, 0.1887],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0., 0., 0., 0., 0., 0., 1.], device='cuda:0')
# epoch 152, loss: 0.37750446796417236
# tensor([0.2207, 0.0599, 0.0956, 0.0491, 0.2097, 0.0741, 0.2911],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# epoch 153, loss: 0.3790266811847687
# tensor([0.1694, 0.1867, 0.0710, 0.0634, 0.1949, 0.1391, 0.1754],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1667, 0.1667, 0.1667, 0.0000, 0.1667, 0.1667, 0.1667],
#        device='cuda:0')
# epoch 154, loss: 0.37764817476272583
# tensor([0.1894, 0.1635, 0.1313, 0.0671, 0.1895, 0.0942, 0.1649],
#        device='cuda:0', grad_fn=<SelectBackward>) tensor([0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429],
#        device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/miniconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# ~/repo/connect4/connect4/neural/nn_pytorch.py in __getitem__(self, idx)
#     374             return (self.boards[idx],
#     375                     self.values[idx],
# --> 376                     self.policies[idx])
#
# KeyboardInterrupt:
